# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import OneHotEncoder, StandardScaler, PolynomialFeatures
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.model_selection import train_test_split, GridSearchCV, cross_val_score
from sklearn.linear_model import Ridge
from sklearn.metrics import mean_squared_error, r2_score
from statsmodels.stats.outliers_influence import variance_inflation_factor
import statsmodels.api as sm
from pyDOE2 import lhs

# Set random seed for reproducibility
np.random.seed(42)

# Define the ranges and probabilities for each feature
feature_ranges = {
    "Total service life time (hours)": (0, 150000),
    "Service and maintenance condition": ["Good", "Average", "Rather poor", "Poor"],
    "Type of blade": ["Straight tilt dozer", "U-tilt dozer", "Semi U-tilt dozer", "Angle dozer"],
    "Maximum blade capacity (m³)": [4.8, 6.8, 8.8, 11.8],
    "Blade sharpness": ["Good", "Average", "Rather poor", "Poor"],
    "Ripper used?": ["Yes", "No"],
    "Time between gear shifting (seconds)": ["Less than 5", "Between 5~10", "More than 10"],
    "Operator’s skill": ["Good", "Average", "Rather poor", "Poor"],
    "Overall operator’s condition during the operation": ["Good", "Average", "Rather poor", "Poor"],
    "Site management quality": ["Good", "Average", "Rather poor", "Poor"],
    "Number of consecutive operational days": (0, 100),
    "Predominant soil type": ["Sand", "Sandy clay", "Clay", "Gravel", "Broken rocks"],
    "Big pieces of rock exist on the site?": ["No", "Rarely", "Commonly"],
    "Equipment maneuvering space": ["Easy", "Average", "Rather difficult", "Difficult"],
    "Ground grade (%)": (-25, 25),
    "Dozing distance (m)": (0, 150),
    "Operation time": ["Morning", "Afternoon", "Night"],
    "Average temperature during operation (°C)": (-15, 45)
}

# Assign numerical values for categorical data
ordinal_mapping = {
    "Service and maintenance condition": {"Good": 4, "Average": 3, "Rather poor": 2, "Poor": 1},
    "Blade sharpness": {"Good": 4, "Average": 3, "Rather poor": 2, "Poor": 1},
    "Ripper used?": {"Yes": 1, "No": 0},
    "Time between gear shifting (seconds)": {"Less than 5": 3, "Between 5~10": 2, "More than 10": 1},
    "Operator’s skill": {"Good": 4, "Average": 3, "Rather poor": 2, "Poor": 1},
    "Overall operator’s condition during the operation": {"Good": 4, "Average": 3, "Rather poor": 2, "Poor": 1},
    "Site management quality": {"Good": 4, "Average": 3, "Rather poor": 2, "Poor": 1},
    "Predominant soil type": {"Sand": 1, "Sandy clay": 2, "Clay": 3, "Gravel": 4, "Broken rocks": 5},
    "Big pieces of rock exist on the site?": {"No": 1, "Rarely": 2, "Commonly": 3},
    "Equipment maneuvering space": {"Easy": 4, "Average": 3, "Rather difficult": 2, "Difficult": 1},
    "Operation time": {"Morning": 3, "Afternoon": 2, "Night": 1},
    "Type of blade": {"Straight tilt dozer": 1, "U-tilt dozer": 2, "Semi U-tilt dozer": 3, "Angle dozer": 4}
}

# Function to generate dataset using Latin Hypercube Sampling
def generate_lhs_dataset(n_samples):
    data = lhs(len(feature_ranges), samples=n_samples)
    df = pd.DataFrame(data, columns=feature_ranges.keys())

    for feature, value_range in feature_ranges.items():
        if isinstance(value_range, tuple):
            df[feature] = df[feature] * (value_range[1] - value_range[0]) + value_range[0]
        else:
            df[feature] = df[feature].apply(lambda x: np.random.choice(value_range))

    for feature, mapping in ordinal_mapping.items():
        df[feature] = df[feature].map(mapping)
    
    # Add noise to the equation
    def calculate_amp(row):
        noise = np.random.normal(0, 2)
        return (0.00001 * row["Total service life time (hours)"] +
                row["Service and maintenance condition"] +
                row["Type of blade"] +
                0.1 * row["Maximum blade capacity (m³)"] +
                row["Blade sharpness"] +
                10 * row["Ripper used?"] +
                row["Time between gear shifting (seconds)"] +
                row["Operator’s skill"] +
                row["Overall operator’s condition during the operation"] +
                row["Site management quality"] +
                0.01 * row["Number of consecutive operational days"] +
                row["Predominant soil type"] +
                row["Big pieces of rock exist on the site?"] +
                row["Equipment maneuvering space"] +
                0.01 * row["Ground grade (%)"] +
                0.1 * row["Dozing distance (m)"] +
                row["Operation time"] +
                0.1 * row["Average temperature during operation (°C)"] +
                noise)

    df["Actual Measured Productivity (Lm³/Hour)"] = df.apply(calculate_amp, axis=1)
    
    return df

# Generate the dataset
lhs_dataset = generate_lhs_dataset(5000)
print(lhs_dataset.head())

# Define the preprocessing steps
quantitative_columns = [
    "Total service life time (hours)", 
    "Number of consecutive operational days", 
    "Ground grade (%)", 
    "Dozing distance (m)", 
    "Average temperature during operation (°C)"
]

ordinal_columns = [
    "Service and maintenance condition", 
    "Blade sharpness", 
    "Time between gear shifting (seconds)", 
    "Operator’s skill", 
    "Overall operator’s condition during the operation", 
    "Site management quality", 
    "Predominant soil type", 
    "Big pieces of rock exist on the site?", 
    "Equipment maneuvering space"
]

nominal_columns = [
    "Type of blade", 
    "Maximum blade capacity (m³)", 
    "Ripper used?", 
    "Operation time"
]

# Preprocessing pipelines for quantitative and categorical features
numeric_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='median')),
    ('scaler', StandardScaler())
])

nominal_transformer = OneHotEncoder(drop='first')

preprocessor = ColumnTransformer(
    transformers=[
        ('num', numeric_transformer, quantitative_columns),
        ('nom', nominal_transformer, nominal_columns)
    ])

# Apply preprocessing
X = lhs_dataset.drop(columns=['Actual Measured Productivity (Lm³/Hour)'])
y = lhs_dataset['Actual Measured Productivity (Lm³/Hour)']

# Transform features
X_preprocessed = preprocessor.fit_transform(X)

# Add polynomial features
poly = PolynomialFeatures(degree=2, interaction_only=False, include_bias=False)
X_poly = poly.fit_transform(X_preprocessed)

# Get feature names after preprocessing and polynomial transformation
numeric_features = preprocessor.transformers_[0][2]
nominal_features = preprocessor.transformers_[1][1].get_feature_names_out(nominal_columns)
all_features = np.concatenate([numeric_features, nominal_features])
poly_features = poly.get_feature_names_out(all_features)

# Convert to DataFrame
X_poly_df = pd.DataFrame(X_poly, columns=poly_features)

# Ensure data types are correct
X_poly_df = X_poly_df.apply(pd.to_numeric)

# Calculate VIF
X_poly_df_const = sm.add_constant(X_poly_df)  # Add constant term
vif_data = pd.DataFrame()
vif_data["feature"] = X_poly_df_const.columns
vif_data["VIF"] = [variance_inflation_factor(X_poly_df_const.values, i) for i in range(len(X_poly_df_const.columns))]

print(vif_data)

# Drop features with high VIF (typically VIF > 10 indicates high multicollinearity), excluding 'const'
high_vif_features = vif_data[(vif_data["VIF"] > 10) & (vif_data["feature"] != "const")]["feature"].tolist()
X_poly_df_reduced = X_poly_df.drop(columns=high_vif_features)

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_poly_df_reduced, y, test_size=0.2, random_state=42)

# Define Ridge Regression model
ridge = Ridge()

# Define parameter grid for GridSearchCV
param_grid = {
    'alpha': np.logspace(-6, 6, 13)
}

# Train Ridge regression model with cross-validation to find the best alpha
ridge_cv = GridSearchCV(ridge, param_grid, cv=5, scoring='r2')
ridge_cv.fit(X_train, y_train)

# Best alpha
best_alpha = ridge_cv.best_params_['alpha']
print(f"Best alpha for Ridge Regression: {best_alpha}")

# Train the initial Ridge regression model with the best alpha
initial_ridge_model = Ridge(alpha=best_alpha)
initial_ridge_model.fit(X_train, y_train)

# Evaluate the initial model on the test set
initial_y_pred = initial_ridge_model.predict(X_test)
initial_r2 = r2_score(y_test, initial_y_pred)
initial_mse = mean_squared_error(y_test, initial_y_pred)
print(f"Initial Ridge Regression R²: {initial_r2:.4f}")
print(f"Initial Ridge Regression MSE: {initial_mse:.4f}")

# Perform cross-validation for the initial model
cv_scores = cross_val_score(initial_ridge_model, X_train, y_train, cv=5, scoring='r2')
print(f"Initial Ridge Regression CV R²: {np.mean(cv_scores):.4f} ± {np.std(cv_scores):.4f}")

# Fit OLS model for p-value inspection
X_train_const = sm.add_constant(X_train)
ols_model = sm.OLS(y_train, X_train_const).fit()
print(ols_model.summary())

# Iteratively remove features with p-values > 0.05
while True:
    p_values = ols_model.pvalues
    max_p_value = p_values.max()
    if max_p_value > 0.05:
        excluded_feature = p_values.idxmax()
        X_train_const = X_train_const.drop(columns=excluded_feature)
        X_train = X_train.drop(columns=excluded_feature)
        X_test = X_test.drop(columns=excluded_feature)
        ols_model = sm.OLS(y_train, X_train_const).fit()
    else:
        break

print(ols_model.summary())

# Train the final Ridge regression model
final_ridge_model = Ridge(alpha=best_alpha)
final_ridge_model.fit(X_train, y_train)

# Evaluate the final model on the test set
final_y_pred = final_ridge_model.predict(X_test)
final_r2 = r2_score(y_test, final_y_pred)
final_mse = mean_squared_error(y_test, final_y_pred)
print(f"Final Ridge Regression R²: {final_r2:.4f}")
print(f"Final Ridge Regression MSE: {final_mse:.4f}")

# Perform cross-validation for the final model
final_cv_scores = cross_val_score(final_ridge_model, X_train, y_train, cv=5, scoring='r2')
print(f"Final Ridge Regression CV R²: {np.mean(final_cv_scores):.4f} ± {np.std(final_cv_scores):.4f}")

# Plot actual vs predicted for final model
plt.figure(figsize=(8, 6))
plt.scatter(y_test, final_y_pred, alpha=0.5)
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'r--')
plt.xlabel('Actual')
plt.ylabel('Predicted')
plt.title('Actual vs Predicted Productivity (Final Ridge Model)')
plt.show()

# Plot residuals for final model
final_residuals = y_test - final_y_pred
plt.figure(figsize=(8, 6))
plt.scatter(final_y_pred, final_residuals, alpha=0.5)
plt.hlines(0, xmin=final_y_pred.min(), xmax=final_y_pred.max(), colors='r', linestyles='dashed')
plt.xlabel('Predicted')
plt.ylabel('Residuals')
plt.title('Residuals Plot (Final Ridge Model)')
plt.show()
# Out:
#    Total service life time (hours)  Service and maintenance condition  \
# 0                     49320.016129                                  2
# 1                    129087.281875                                  1
# 2                     17810.239006                                  4
# 3                     79087.910462                                  2
# 4                    122139.555848                                  2
#
#    Type of blade  Maximum blade capacity (m³)  Blade sharpness  Ripper used?  \
# 0              3                          8.8                1             1
# 1              3                         11.8                1             0
# 2              3                          8.8                3             0
# 3              3                         11.8                4             0
# 4              4                         11.8                4             1
#
#    Time between gear shifting (seconds)  Operator’s skill  \
# 0                                     1                 2
# 1                                     2                 4
# 2                                     1                 1
# 3                                     3                 2
# 4                                     1                 1
#
#    Overall operator’s condition during the operation  Site management quality  \
# 0                                                  4                        4
# 1                                                  4                        2
# 2                                                  1                        3
# 3                                                  2                        1
# 4                                                  2                        3
#
#    Number of consecutive operational days  Predominant soil type  \
# 0                                8.276781                      4
# 1                               44.302412                      5
# 2                               86.386646                      4
# 3                                8.334323                      1
# 4                               76.743768                      3
#
#    Big pieces of rock exist on the site?  Equipment maneuvering space  \
# 0                                      2                            4
# 1                                      2                            1
# 2                                      2                            3
# 3                                      1                            2
# 4                                      1                            1
#
#    Ground grade (%)  Dozing distance (m)  Operation time  \
# 0         19.943841            73.865841               3
# 1          5.251496            50.578804               2
# 2          5.553613            77.843976               1
# 3          7.765830            67.784988               2
# 4         -6.614401            72.495429               2
#
#    Average temperature during operation (°C)  \
# 0                                   7.479389
# 1                                  26.852919
# 2                                   2.519622
# 3                                  -5.869012
# 4                                  -0.990542
#
#    Actual Measured Productivity (Lm³/Hour)
# 0                                49.245303
# 1                                41.075387
# 2                                37.183857
# 3                                33.201496
# 4                                44.253419
# C:\Users\tugbe\anaconda3\lib\site-packages\statsmodels\regression\linear_model.py:1736: RuntimeWarning: invalid value encountered in double_scalars
#   return 1 - self.ssr/self.centered_tss
#                                     feature           VIF
# 0                                     const  3.913160e+01
# 1           Total service life time (hours)  9.684891e+00
# 2    Number of consecutive operational days  9.872661e+00
# 3                          Ground grade (%)  9.693533e+00
# 4                       Dozing distance (m)  9.636584e+00
# ..                                      ...           ...
# 115         Ripper used?_1 Operation time_2  3.400359e+00
# 116         Ripper used?_1 Operation time_3  3.460612e+00
# 117                      Operation time_2^2  3.844482e+08
# 118       Operation time_2 Operation time_3           NaN
# 119                      Operation time_3^2  1.960935e+04
#
# [120 rows x 2 columns]
# Best alpha for Ridge Regression: 10.0
# Initial Ridge Regression R²: 0.7032
# Initial Ridge Regression MSE: 18.5233
# Initial Ridge Regression CV R²: 0.7102 ± 0.0160
#                                        OLS Regression Results
# ===================================================================================================
# Dep. Variable:     Actual Measured Productivity (Lm³/Hour)   R-squared:                       0.727
# Model:                                                 OLS   Adj. R-squared:                  0.720
# Method:                                      Least Squares   F-statistic:                     110.5
# Date:                                     Sun, 23 Jun 2024   Prob (F-statistic):               0.00
# Time:                                             16:44:32   Log-Likelihood:                -11453.
# No. Observations:                                     4000   AIC:                         2.310e+04
# Df Residuals:                                         3905   BIC:                         2.369e+04
# Df Model:                                               94
# Covariance Type:                                 nonrobust
# ====================================================================================================================================================
#                                                                                        coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------------------------------------------
# const                                                                               38.6255      0.210    184.280      0.000      38.215      39.036
# Total service life time (hours)                                                      0.3564      0.210      1.700      0.089      -0.055       0.767
# Number of consecutive operational days                                               0.1362      0.210      0.648      0.517      -0.276       0.548
# Ground grade (%)                                                                     0.3126      0.210      1.488      0.137      -0.099       0.724
# Dozing distance (m)                                                                  4.5954      0.209     22.018      0.000       4.186       5.005
# Average temperature during operation (°C)                                            1.6779      0.209      8.021      0.000       1.268       2.088
# Total service life time (hours)^2                                                    0.0945      0.077      1.231      0.218      -0.056       0.245
# Total service life time (hours) Number of consecutive operational days              -0.0454      0.070     -0.652      0.515      -0.182       0.091
# Total service life time (hours) Ground grade (%)                                     0.0426      0.069      0.620      0.535      -0.092       0.178
# Total service life time (hours) Dozing distance (m)                                  0.0566      0.069      0.820      0.412      -0.079       0.192
# Total service life time (hours) Average temperature during operation (°C)            0.0967      0.070      1.389      0.165      -0.040       0.233
# Total service life time (hours) Type of blade_2                                      0.1115      0.195      0.571      0.568      -0.272       0.495
# Total service life time (hours) Type of blade_3                                      0.0100      0.194      0.051      0.959      -0.371       0.391
# Total service life time (hours) Type of blade_4                                      0.0294      0.196      0.151      0.880      -0.354       0.413
# Total service life time (hours) Maximum blade capacity (m³)_6.8                      0.2231      0.192      1.159      0.247      -0.154       0.600
# Total service life time (hours) Maximum blade capacity (m³)_8.8                      0.2595      0.194      1.337      0.181      -0.121       0.640
# Total service life time (hours) Maximum blade capacity (m³)_11.8                     0.1904      0.196      0.972      0.331      -0.194       0.575
# Total service life time (hours) Ripper used?_1                                      -0.0544      0.138     -0.394      0.693      -0.325       0.216
# Total service life time (hours) Operation time_2                                    -0.1889      0.167     -1.133      0.257      -0.516       0.138
# Total service life time (hours) Operation time_3                                    -0.1868      0.170     -1.097      0.273      -0.521       0.147
# Number of consecutive operational days^2                                             0.0328      0.077      0.426      0.670      -0.118       0.184
# Number of consecutive operational days Ground grade (%)                              0.0119      0.069      0.172      0.863      -0.124       0.148
# Number of consecutive operational days Dozing distance (m)                          -0.0468      0.068     -0.689      0.491      -0.180       0.086
# Number of consecutive operational days Average temperature during operation (°C)     0.0141      0.069      0.204      0.839      -0.121       0.149
# Number of consecutive operational days Type of blade_2                               0.3181      0.194      1.640      0.101      -0.062       0.698
# Number of consecutive operational days Type of blade_3                               0.0928      0.195      0.477      0.633      -0.289       0.474
# Number of consecutive operational days Type of blade_4                               0.4861      0.196      2.480      0.013       0.102       0.870
# Number of consecutive operational days Maximum blade capacity (m³)_6.8              -0.0809      0.190     -0.425      0.671      -0.454       0.292
# Number of consecutive operational days Maximum blade capacity (m³)_8.8              -0.1235      0.194     -0.638      0.523      -0.503       0.256
# Number of consecutive operational days Maximum blade capacity (m³)_11.8             -0.0680      0.198     -0.344      0.731      -0.456       0.320
# Number of consecutive operational days Ripper used?_1                                0.0361      0.137      0.263      0.793      -0.233       0.305
# Number of consecutive operational days Operation time_2                             -0.1487      0.166     -0.896      0.370      -0.474       0.177
# Number of consecutive operational days Operation time_3                              0.0866      0.169      0.512      0.609      -0.245       0.418
# Ground grade (%)^2                                                                  -0.0677      0.077     -0.885      0.376      -0.218       0.082
# Ground grade (%) Dozing distance (m)                                                 0.0224      0.069      0.326      0.744      -0.112       0.157
# Ground grade (%) Average temperature during operation (°C)                           0.0085      0.070      0.122      0.903      -0.128       0.145
# Ground grade (%) Type of blade_2                                                    -0.0234      0.197     -0.119      0.905      -0.409       0.362
# Ground grade (%) Type of blade_3                                                    -0.1970      0.195     -1.008      0.313      -0.580       0.186
# Ground grade (%) Type of blade_4                                                    -0.0925      0.197     -0.469      0.639      -0.479       0.294
# Ground grade (%) Maximum blade capacity (m³)_6.8                                    -0.1540      0.191     -0.806      0.420      -0.529       0.221
# Ground grade (%) Maximum blade capacity (m³)_8.8                                    -0.0960      0.196     -0.490      0.624      -0.480       0.288
# Ground grade (%) Maximum blade capacity (m³)_11.8                                    0.0067      0.192      0.035      0.972      -0.370       0.384
# Ground grade (%) Ripper used?_1                                                     -0.0078      0.137     -0.057      0.955      -0.277       0.262
# Ground grade (%) Operation time_2                                                    0.0087      0.168      0.051      0.959      -0.321       0.338
# Ground grade (%) Operation time_3                                                    0.1104      0.170      0.651      0.515      -0.222       0.443
# Dozing distance (m)^2                                                               -0.0419      0.077     -0.544      0.587      -0.193       0.109
# Dozing distance (m) Average temperature during operation (°C)                       -0.1120      0.069     -1.613      0.107      -0.248       0.024
# Dozing distance (m) Type of blade_2                                                 -0.2691      0.194     -1.385      0.166      -0.650       0.112
# Dozing distance (m) Type of blade_3                                                 -0.2046      0.196     -1.046      0.296      -0.588       0.179
# Dozing distance (m) Type of blade_4                                                 -0.4419      0.195     -2.267      0.023      -0.824      -0.060
# Dozing distance (m) Maximum blade capacity (m³)_6.8                                  0.0726      0.192      0.378      0.705      -0.304       0.449
# Dozing distance (m) Maximum blade capacity (m³)_8.8                                  0.1139      0.194      0.587      0.557      -0.267       0.494
# Dozing distance (m) Maximum blade capacity (m³)_11.8                                -0.1396      0.197     -0.710      0.478      -0.525       0.246
# Dozing distance (m) Ripper used?_1                                                   0.0245      0.138      0.177      0.859      -0.246       0.295
# Dozing distance (m) Operation time_2                                                 0.1034      0.167      0.619      0.536      -0.224       0.431
# Dozing distance (m) Operation time_3                                                -0.0566      0.169     -0.335      0.738      -0.388       0.275
# Average temperature during operation (°C)^2                                         -0.0297      0.077     -0.387      0.699      -0.180       0.121
# Average temperature during operation (°C) Type of blade_2                            0.0079      0.198      0.040      0.968      -0.380       0.396
# Average temperature during operation (°C) Type of blade_3                            0.0018      0.197      0.009      0.993      -0.384       0.387
# Average temperature during operation (°C) Type of blade_4                           -0.0729      0.195     -0.374      0.709      -0.455       0.309
# Average temperature during operation (°C) Maximum blade capacity (m³)_6.8           -0.0958      0.193     -0.497      0.619      -0.474       0.282
# Average temperature during operation (°C) Maximum blade capacity (m³)_8.8           -0.2132      0.194     -1.096      0.273      -0.595       0.168
# Average temperature during operation (°C) Maximum blade capacity (m³)_11.8          -0.0807      0.196     -0.411      0.681      -0.466       0.304
# Average temperature during operation (°C) Ripper used?_1                             0.2033      0.138      1.470      0.142      -0.068       0.474
# Average temperature during operation (°C) Operation time_2                           0.2744      0.167      1.647      0.100      -0.052       0.601
# Average temperature during operation (°C) Operation time_3                           0.1437      0.172      0.835      0.404      -0.194       0.481
# Type of blade_2 Type of blade_3                                                   -1.09e-15   2.65e-16     -4.105      0.000   -1.61e-15   -5.69e-16
# Type of blade_2 Type of blade_4                                                  -2.911e-15   2.89e-16    -10.080      0.000   -3.48e-15   -2.34e-15
# Type of blade_2 Maximum blade capacity (m³)_6.8                                     -1.7817      0.378     -4.719      0.000      -2.522      -1.041
# Type of blade_2 Maximum blade capacity (m³)_8.8                                     -1.2532      0.395     -3.173      0.002      -2.028      -0.479
# Type of blade_2 Maximum blade capacity (m³)_11.8                                    -1.2794      0.387     -3.303      0.001      -2.039      -0.520
# Type of blade_2 Ripper used?_1                                                       4.7447      0.319     14.864      0.000       4.119       5.371
# Type of blade_2 Operation time_2                                                    -0.3424      0.339     -1.010      0.313      -1.007       0.322
# Type of blade_2 Operation time_3                                                     0.2305      0.358      0.643      0.520      -0.472       0.933
# Type of blade_3 Type of blade_4                                                   1.715e-17   2.81e-16      0.061      0.951   -5.35e-16    5.69e-16
# Type of blade_3 Maximum blade capacity (m³)_6.8                                     -0.9311      0.373     -2.496      0.013      -1.663      -0.200
# Type of blade_3 Maximum blade capacity (m³)_8.8                                     -1.0453      0.374     -2.797      0.005      -1.778      -0.313
# Type of blade_3 Maximum blade capacity (m³)_11.8                                    -0.3285      0.387     -0.849      0.396      -1.087       0.430
# Type of blade_3 Ripper used?_1                                                       5.1041      0.312     16.347      0.000       4.492       5.716
# Type of blade_3 Operation time_2                                                    -0.2837      0.342     -0.831      0.406      -0.953       0.386
# Type of blade_3 Operation time_3                                                     0.6982      0.364      1.920      0.055      -0.015       1.411
# Type of blade_4 Maximum blade capacity (m³)_6.8                                     -0.3414      0.379     -0.900      0.368      -1.085       0.403
# Type of blade_4 Maximum blade capacity (m³)_8.8                                      0.2458      0.377      0.652      0.514      -0.493       0.985
# Type of blade_4 Maximum blade capacity (m³)_11.8                                    -0.0478      0.384     -0.124      0.901      -0.801       0.706
# Type of blade_4 Ripper used?_1                                                       5.3699      0.317     16.947      0.000       4.749       5.991
# Type of blade_4 Operation time_2                                                     0.1542      0.335      0.460      0.645      -0.502       0.811
# Type of blade_4 Operation time_3                                                     0.7733      0.364      2.124      0.034       0.060       1.487
# Maximum blade capacity (m³)_6.8 Maximum blade capacity (m³)_8.8                   9.595e-16   1.37e-16      7.029      0.000    6.92e-16    1.23e-15
# Maximum blade capacity (m³)_6.8 Maximum blade capacity (m³)_11.8                   5.68e-17   1.59e-16      0.356      0.722   -2.56e-16     3.7e-16
# Maximum blade capacity (m³)_6.8 Ripper used?_1                                       3.6747      0.306     12.018      0.000       3.075       4.274
# Maximum blade capacity (m³)_6.8 Operation time_2                                    -0.5766      0.347     -1.662      0.097      -1.257       0.104
# Maximum blade capacity (m³)_6.8 Operation time_3                                    -0.5066      0.373     -1.357      0.175      -1.239       0.226
# Maximum blade capacity (m³)_8.8 Maximum blade capacity (m³)_11.8                  8.971e-17   8.41e-17      1.067      0.286   -7.51e-17    2.55e-16
# Maximum blade capacity (m³)_8.8 Ripper used?_1                                       3.5287      0.316     11.151      0.000       2.908       4.149
# Maximum blade capacity (m³)_8.8 Operation time_2                                    -0.7122      0.364     -1.957      0.050      -1.426       0.001
# Maximum blade capacity (m³)_8.8 Operation time_3                                     0.0743      0.359      0.207      0.836      -0.629       0.778
# Maximum blade capacity (m³)_11.8 Ripper used?_1                                      3.5541      0.317     11.207      0.000       2.932       4.176
# Maximum blade capacity (m³)_11.8 Operation time_2                                   -0.6763      0.363     -1.865      0.062      -1.387       0.035
# Maximum blade capacity (m³)_11.8 Operation time_3                                   -0.0966      0.374     -0.258      0.796      -0.830       0.637
# Ripper used?_1 Operation time_2                                                      3.5068      0.281     12.491      0.000       2.956       4.057
# Ripper used?_1 Operation time_3                                                      3.3646      0.287     11.743      0.000       2.803       3.926
# Operation time_2 Operation time_3                                                         0          0        nan        nan           0           0
# ==============================================================================
# Omnibus:                        1.575   Durbin-Watson:                   2.008
# Prob(Omnibus):                  0.455   Jarque-Bera (JB):                1.605
# Skew:                           0.047   Prob(JB):                        0.448
# Kurtosis:                       2.972   Cond. No.                     1.15e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 2.1e-28. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
#                                        OLS Regression Results
# ===================================================================================================
# Dep. Variable:     Actual Measured Productivity (Lm³/Hour)   R-squared:                       0.723
# Model:                                                 OLS   Adj. R-squared:                  0.722
# Method:                                      Least Squares   F-statistic:                     472.0
# Date:                                     Sun, 23 Jun 2024   Prob (F-statistic):               0.00
# Time:                                             16:44:37   Log-Likelihood:                -11480.
# No. Observations:                                     4000   AIC:                         2.301e+04
# Df Residuals:                                         3977   BIC:                         2.315e+04
# Df Model:                                               22
# Covariance Type:                                 nonrobust
# ==========================================================================================================================
#                                                              coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------------------------------
# const                                                     38.6472      0.104    370.266      0.000      38.443      38.852
# Total service life time (hours)                            0.3953      0.068      5.818      0.000       0.262       0.529
# Ground grade (%)                                           0.2043      0.068      3.005      0.003       0.071       0.338
# Dozing distance (m)                                        4.4136      0.068     65.154      0.000       4.281       4.546
# Average temperature during operation (°C)                  1.8060      0.068     26.505      0.000       1.672       1.940
# Number of consecutive operational days Type of blade_2     0.3953      0.134      2.942      0.003       0.132       0.659
# Number of consecutive operational days Type of blade_4     0.5223      0.138      3.789      0.000       0.252       0.793
# Type of blade_2 Maximum blade capacity (m³)_6.8           -1.8302      0.332     -5.507      0.000      -2.482      -1.179
# Type of blade_2 Maximum blade capacity (m³)_8.8           -1.3005      0.341     -3.815      0.000      -1.969      -0.632
# Type of blade_2 Maximum blade capacity (m³)_11.8          -1.2715      0.326     -3.906      0.000      -1.910      -0.633
# Type of blade_2 Ripper used?_1                             4.6444      0.287     16.208      0.000       4.083       5.206
# Type of blade_3 Maximum blade capacity (m³)_6.8           -0.8881      0.313     -2.842      0.005      -1.501      -0.275
# Type of blade_3 Maximum blade capacity (m³)_8.8           -0.9175      0.316     -2.904      0.004      -1.537      -0.298
# Type of blade_3 Ripper used?_1                             5.1020      0.267     19.130      0.000       4.579       5.625
# Type of blade_4 Ripper used?_1                             5.6253      0.252     22.358      0.000       5.132       6.119
# Maximum blade capacity (m³)_6.8 Ripper used?_1             3.4472      0.261     13.216      0.000       2.936       3.959
# Maximum blade capacity (m³)_6.8 Operation time_2          -0.7618      0.287     -2.655      0.008      -1.324      -0.199
# Maximum blade capacity (m³)_8.8 Ripper used?_1             3.6158      0.271     13.344      0.000       3.085       4.147
# Maximum blade capacity (m³)_8.8 Operation time_2          -0.8380      0.303     -2.768      0.006      -1.431      -0.245
# Maximum blade capacity (m³)_11.8 Ripper used?_1            3.4635      0.264     13.109      0.000       2.946       3.982
# Maximum blade capacity (m³)_11.8 Operation time_2         -0.8891      0.292     -3.040      0.002      -1.463      -0.316
# Ripper used?_1 Operation time_2                            3.5157      0.251     14.003      0.000       3.023       4.008
# Ripper used?_1 Operation time_3                            3.5879      0.220     16.300      0.000       3.156       4.019
# Operation time_2 Operation time_3                               0          0        nan        nan           0           0
# ==============================================================================
# Omnibus:                        1.793   Durbin-Watson:                   2.017
# Prob(Omnibus):                  0.408   Jarque-Bera (JB):                1.808
# Skew:                           0.051   Prob(JB):                        0.405
# Kurtosis:                       2.984   Cond. No.                          inf
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is      0. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# Final Ridge Regression R²: 0.6991
# Final Ridge Regression MSE: 18.7784
# Final Ridge Regression CV R²: 0.7183 ± 0.0167
# C:\Users\tugbe\anaconda3\lib\site-packages\statsmodels\regression\linear_model.py:1918: RuntimeWarning: divide by zero encountered in double_scalars
#   return np.sqrt(eigvals[0]/eigvals[-1])
