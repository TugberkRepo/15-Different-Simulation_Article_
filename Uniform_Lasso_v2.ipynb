# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import OneHotEncoder, StandardScaler, PolynomialFeatures
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.linear_model import Lasso
from sklearn.metrics import mean_squared_error, r2_score
from statsmodels.stats.outliers_influence import variance_inflation_factor
import statsmodels.api as sm

# Set random seed for reproducibility
np.random.seed(42)

# Define the sample values as given in the table
sample_values = {
    "Total service life time (hours)": 100000,
    "Service and maintenance condition": "Good",
    "Type of blade": "U-tilt",
    "Maximum blade capacity (m³)": 8.8,
    "Blade sharpness": "Average",
    "Ripper used?": "Yes",
    "Time between gear shifting (seconds)": "Less than 5",
    "Operator’s skill": "Good",
    "Overall operator’s condition during the operation": "Good",
    "Site management quality": "Average",
    "Number of consecutive operational days": 7,
    "Predominant soil type": "Broken rocks",
    "Big pieces of rock exist on the site?": "Commonly",
    "Equipment maneuvering space": "Easy",
    "Ground grade (%)": -10,
    "Dozing distance (m)": 20,
    "Operation time": "Morning",
    "Average temperature during operation (°C)": 20
}

# Define the ranges and probabilities for each feature
feature_ranges = {
    "Total service life time (hours)": (0, 150000),
    "Service and maintenance condition": ["Good", "Average", "Rather poor", "Poor"],
    "Type of blade": ["Straight tilt dozer", "U-tilt dozer", "Semi U-tilt dozer", "Angle dozer"],
    "Maximum blade capacity (m³)": [4.8, 6.8, 8.8, 11.8],
    "Blade sharpness": ["Good", "Average", "Rather poor", "Poor"],
    "Ripper used?": ["Yes", "No"],
    "Time between gear shifting (seconds)": ["Less than 5", "Between 5~10", "More than 10"],
    "Operator’s skill": ["Good", "Average", "Rather poor", "Poor"],
    "Overall operator’s condition during the operation": ["Good", "Average", "Rather poor", "Poor"],
    "Site management quality": ["Good", "Average", "Rather poor", "Poor"],
    "Number of consecutive operational days": (0, 100),
    "Predominant soil type": ["Sand", "Sandy clay", "Clay", "Gravel", "Broken rocks"],
    "Big pieces of rock exist on the site?": ["No", "Rarely", "Commonly"],
    "Equipment maneuvering space": ["Easy", "Average", "Rather difficult", "Difficult"],
    "Ground grade (%)": (-25, 25),
    "Dozing distance (m)": (0, 150),
    "Operation time": ["Morning", "Afternoon", "Night"],
    "Average temperature during operation (°C)": (-15, 45)
}

# Assign numerical values for categorical data
ordinal_mapping = {
    "Service and maintenance condition": {"Good": 4, "Average": 3, "Rather poor": 2, "Poor": 1},
    "Blade sharpness": {"Good": 4, "Average": 3, "Rather poor": 2, "Poor": 1},
    "Ripper used?": {"Yes": 1, "No": 0},
    "Time between gear shifting (seconds)": {"Less than 5": 3, "Between 5~10": 2, "More than 10": 1},
    "Operator’s skill": {"Good": 4, "Average": 3, "Rather poor": 2, "Poor": 1},
    "Overall operator’s condition during the operation": {"Good": 4, "Average": 3, "Rather poor": 2, "Poor": 1},
    "Site management quality": {"Good": 4, "Average": 3, "Rather poor": 2, "Poor": 1},
    "Predominant soil type": {"Sand": 1, "Sandy clay": 2, "Clay": 3, "Gravel": 4, "Broken rocks": 5},
    "Big pieces of rock exist on the site?": {"No": 1, "Rarely": 2, "Commonly": 3},
    "Equipment maneuvering space": {"Easy": 4, "Average": 3, "Rather difficult": 2, "Difficult": 1},
    "Operation time": {"Morning": 3, "Afternoon": 2, "Night": 1},
    "Type of blade": {"Straight tilt dozer": 1, "U-tilt dozer": 2, "Semi U-tilt dozer": 3, "Angle dozer": 4}
}

# Create a function to generate the dataset
def generate_dataset(n_samples):
    data = {}
    
    for feature, value_range in feature_ranges.items():
        if isinstance(value_range, tuple):
            data[feature] = np.random.uniform(value_range[0], value_range[1], n_samples)
        else:
            data[feature] = np.random.choice(value_range, n_samples)
    
    df = pd.DataFrame(data)
    
    for feature, mapping in ordinal_mapping.items():
        df[feature] = df[feature].map(mapping)
    
    # Use the given sample values to create an equation for AMP and add noise
    def calculate_amp(row):
        noise = np.random.normal(0, 2)  # Adding Gaussian noise with mean 0 and standard deviation 2
        return (0.00001 * row["Total service life time (hours)"] +
                row["Service and maintenance condition"] +
                row["Type of blade"] +
                0.1 * row["Maximum blade capacity (m³)"] +
                row["Blade sharpness"] +
                10 * row["Ripper used?"] +
                row["Time between gear shifting (seconds)"] +
                row["Operator’s skill"] +
                row["Overall operator’s condition during the operation"] +
                row["Site management quality"] +
                0.01 * row["Number of consecutive operational days"] +
                row["Predominant soil type"] +
                row["Big pieces of rock exist on the site?"] +
                row["Equipment maneuvering space"] +
                0.01 * row["Ground grade (%)"] +
                0.1 * row["Dozing distance (m)"] +
                row["Operation time"] +
                0.1 * row["Average temperature during operation (°C)"] +
                noise)

    df["Actual Measured Productivity (Lm³/Hour)"] = df.apply(calculate_amp, axis=1)
    
    return df

# Generate the dataset
synthetic_dataset = generate_dataset(5000)
print(synthetic_dataset.head())

# Define the preprocessing steps
quantitative_columns = [
    "Total service life time (hours)", 
    "Number of consecutive operational days", 
    "Ground grade (%)", 
    "Dozing distance (m)", 
    "Average temperature during operation (°C)"
]

ordinal_columns = [
    "Service and maintenance condition", 
    "Blade sharpness", 
    "Time between gear shifting (seconds)", 
    "Operator’s skill", 
    "Overall operator’s condition during the operation", 
    "Site management quality", 
    "Predominant soil type", 
    "Big pieces of rock exist on the site?", 
    "Equipment maneuvering space"
]

nominal_columns = [
    "Type of blade", 
    "Maximum blade capacity (m³)", 
    "Ripper used?", 
    "Operation time"
]

# Preprocessing pipelines for quantitative and categorical features
numeric_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='median')),
    ('scaler', StandardScaler())
])

nominal_transformer = OneHotEncoder(drop='first')

preprocessor = ColumnTransformer(
    transformers=[
        ('num', numeric_transformer, quantitative_columns),
        ('nom', nominal_transformer, nominal_columns)
    ])

# Apply preprocessing
X = synthetic_dataset.drop(columns=['Actual Measured Productivity (Lm³/Hour)'])
y = synthetic_dataset['Actual Measured Productivity (Lm³/Hour)']

# Transform features
X_preprocessed = preprocessor.fit_transform(X)

# Add polynomial features
poly = PolynomialFeatures(degree=2, interaction_only=False, include_bias=False)
X_poly = poly.fit_transform(X_preprocessed)

# Get feature names after preprocessing and polynomial transformation
numeric_features = preprocessor.transformers_[0][2]
nominal_features = preprocessor.transformers_[1][1].get_feature_names_out(nominal_columns)
all_features = np.concatenate([numeric_features, nominal_features])
poly_features = poly.get_feature_names_out(all_features)

# Convert to DataFrame
X_poly_df = pd.DataFrame(X_poly, columns=poly_features)

# Ensure data types are correct
X_poly_df = X_poly_df.apply(pd.to_numeric)

# Calculate VIF
X_poly_df_const = sm.add_constant(X_poly_df)  # Add constant term
vif_data = pd.DataFrame()
vif_data["feature"] = X_poly_df_const.columns
vif_data["VIF"] = [variance_inflation_factor(X_poly_df_const.values, i) for i in range(len(X_poly_df_const.columns))]

print(vif_data)

# Drop features with high VIF (typically VIF > 10 indicates high multicollinearity), excluding 'const'
high_vif_features = vif_data[(vif_data["VIF"] > 10) & (vif_data["feature"] != "const")]["feature"].tolist()
X_poly_df_reduced = X_poly_df.drop(columns=high_vif_features)

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_poly_df_reduced, y, test_size=0.2, random_state=42)

# Train Lasso regression model with cross-validation to find the best alpha
lasso = Lasso(max_iter=10000)
param_grid = {'alpha': np.logspace(-6, 1, 8)}
lasso_cv = GridSearchCV(lasso, param_grid, cv=5, scoring='r2')
lasso_cv.fit(X_train, y_train)

# Best alpha
best_alpha = lasso_cv.best_params_['alpha']
print(f"Best alpha for Lasso Regression: {best_alpha}")

# Train the initial Lasso regression model with the best alpha
initial_lasso_model = Lasso(alpha=best_alpha, max_iter=10000)
initial_lasso_model.fit(X_train, y_train)

# Evaluate the initial model on the test set
initial_y_pred = initial_lasso_model.predict(X_test)
initial_r2 = r2_score(y_test, initial_y_pred)
initial_mse = mean_squared_error(y_test, initial_y_pred)
print(f"Initial Lasso Regression R²: {initial_r2:.4f}")
print(f"Initial Lasso Regression MSE: {initial_mse:.4f}")

# Fit OLS model for p-value inspection
X_train_const = sm.add_constant(X_train)
ols_model = sm.OLS(y_train, X_train_const).fit()
print(ols_model.summary())

# Iteratively remove features with p-values > 0.05
while True:
    p_values = ols_model.pvalues
    max_p_value = p_values.max()
    if max_p_value > 0.05:
        excluded_feature = p_values.idxmax()
        X_train_const = X_train_const.drop(columns=excluded_feature)
        X_train = X_train.drop(columns=excluded_feature)
        X_test = X_test.drop(columns=excluded_feature)
        ols_model = sm.OLS(y_train, X_train_const).fit()
    else:
        break

print(ols_model.summary())

# Train the final Lasso regression model
final_lasso_model = Lasso(alpha=best_alpha, max_iter=10000)
final_lasso_model.fit(X_train, y_train)

# Evaluate the final model on the test set
final_y_pred = final_lasso_model.predict(X_test)
final_r2 = r2_score(y_test, final_y_pred)
final_mse = mean_squared_error(y_test, final_y_pred)
print(f"Final Lasso Regression R²: {final_r2:.4f}")
print(f"Final Lasso Regression MSE: {final_mse:.4f}")

# Plot actual vs predicted for final model
plt.figure(figsize=(8, 6))
plt.scatter(y_test, final_y_pred, alpha=0.5)
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'r--')
plt.xlabel('Actual')
plt.ylabel('Predicted')
plt.title('Actual vs Predicted Productivity (Final Lasso Model)')
plt.show()

# Plot residuals for final model
final_residuals = y_test - final_y_pred
plt.figure(figsize=(8, 6))
plt.scatter(final_y_pred, final_residuals, alpha=0.5)
plt.hlines(0, xmin=final_y_pred.min(), xmax=final_y_pred.max(), colors='r', linestyles='dashed')
plt.xlabel('Predicted')
plt.ylabel('Residuals')
plt.title('Residuals Plot (Final Lasso Model)')
plt.show()
# Out:
#    Total service life time (hours)  Service and maintenance condition  \
# 0                     56181.017827                                  2
# 1                    142607.145961                                  1
# 2                    109799.091272                                  2
# 3                     89798.772630                                  1
# 4                     23402.796066                                  1
#
#    Type of blade  Maximum blade capacity (m³)  Blade sharpness  Ripper used?  \
# 0              4                          8.8                2             0
# 1              4                         11.8                3             0
# 2              2                         11.8                2             1
# 3              1                          6.8                1             0
# 4              1                          4.8                1             1
#
#    Time between gear shifting (seconds)  Operator’s skill  \
# 0                                     3                 4
# 1                                     2                 2
# 2                                     2                 2
# 3                                     2                 4
# 4                                     2                 2
#
#    Overall operator’s condition during the operation  Site management quality  \
# 0                                                  4                        4
# 1                                                  4                        2
# 2                                                  4                        4
# 3                                                  2                        2
# 4                                                  2                        3
#
#    Number of consecutive operational days  Predominant soil type  \
# 0                               78.167267                      3
# 1                               37.624005                      2
# 2                               43.274158                      5
# 3                               36.162490                      1
# 4                               31.565072                      4
#
#    Big pieces of rock exist on the site?  Equipment maneuvering space  \
# 0                                      2                            1
# 1                                      2                            4
# 2                                      3                            3
# 3                                      3                            2
# 4                                      3                            4
#
#    Ground grade (%)  Dozing distance (m)  Operation time  \
# 0         -2.118670           140.013329               1
# 1        -20.817414            41.983754               3
# 2         -5.353094            42.872526               2
# 3         -8.863738            72.397722               3
# 4         -5.426141           106.034944               2
#
#    Average temperature during operation (°C)  \
# 0                                   6.852618
# 1                                   7.734460
# 2                                  -3.822288
# 3                                  15.670124
# 4                                  30.934239
#
#    Actual Measured Productivity (Lm³/Hour)
# 0                                45.746975
# 1                                37.876729
# 2                                50.239876
# 3                                34.739399
# 4                                50.918139
# C:\Users\tugbe\anaconda3\lib\site-packages\statsmodels\regression\linear_model.py:1736: RuntimeWarning: invalid value encountered in double_scalars
#   return 1 - self.ssr/self.centered_tss
#                                     feature           VIF
# 0                                     const  5.086709e+01
# 1           Total service life time (hours)  1.076551e+01
# 2    Number of consecutive operational days  1.079333e+01
# 3                          Ground grade (%)  1.051463e+01
# 4                       Dozing distance (m)  1.054788e+01
# ..                                      ...           ...
# 115         Ripper used?_1 Operation time_2  3.375446e+00
# 116         Ripper used?_1 Operation time_3  3.490631e+00
# 117                      Operation time_2^2  1.411074e+07
# 118       Operation time_2 Operation time_3           NaN
# 119                      Operation time_3^2  3.265391e+09
#
# [120 rows x 2 columns]
# Best alpha for Lasso Regression: 0.01
# Initial Lasso Regression R²: 0.6926
# Initial Lasso Regression MSE: 20.3515
#                                        OLS Regression Results
# ===================================================================================================
# Dep. Variable:     Actual Measured Productivity (Lm³/Hour)   R-squared:                       0.695
# Model:                                                 OLS   Adj. R-squared:                  0.688
# Method:                                      Least Squares   F-statistic:                     100.2
# Date:                                     Sun, 23 Jun 2024   Prob (F-statistic):               0.00
# Time:                                             15:57:22   Log-Likelihood:                -11601.
# No. Observations:                                     4000   AIC:                         2.338e+04
# Df Residuals:                                         3910   BIC:                         2.395e+04
# Df Model:                                               89
# Covariance Type:                                 nonrobust
# ====================================================================================================================================================
#                                                                                        coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------------------------------------------
# const                                                                               38.8711      0.216    180.101      0.000      38.448      39.294
# Total service life time (hours)^2                                                    0.0429      0.080      0.537      0.592      -0.114       0.199
# Total service life time (hours) Number of consecutive operational days              -0.0268      0.071     -0.376      0.707      -0.167       0.113
# Total service life time (hours) Ground grade (%)                                     0.0962      0.071      1.354      0.176      -0.043       0.235
# Total service life time (hours) Dozing distance (m)                                 -0.0192      0.071     -0.269      0.788      -0.159       0.121
# Total service life time (hours) Average temperature during operation (°C)            0.0278      0.070      0.396      0.692      -0.110       0.166
# Total service life time (hours) Type of blade_2                                      0.1612      0.179      0.900      0.368      -0.190       0.512
# Total service life time (hours) Type of blade_3                                      0.1368      0.178      0.767      0.443      -0.213       0.486
# Total service life time (hours) Type of blade_4                                      0.0315      0.178      0.177      0.859      -0.317       0.380
# Total service life time (hours) Maximum blade capacity (m³)_6.8                      0.4396      0.180      2.446      0.014       0.087       0.792
# Total service life time (hours) Maximum blade capacity (m³)_8.8                      0.2785      0.174      1.598      0.110      -0.063       0.620
# Total service life time (hours) Maximum blade capacity (m³)_11.8                     0.0412      0.174      0.236      0.813      -0.301       0.383
# Total service life time (hours) Ripper used?_1                                       0.1838      0.136      1.351      0.177      -0.083       0.451
# Total service life time (hours) Operation time_2                                     0.2093      0.159      1.315      0.188      -0.103       0.521
# Total service life time (hours) Operation time_3                                    -0.0100      0.161     -0.062      0.951      -0.326       0.306
# Number of consecutive operational days^2                                             0.0605      0.079      0.763      0.445      -0.095       0.216
# Number of consecutive operational days Ground grade (%)                              0.0414      0.073      0.567      0.571      -0.102       0.184
# Number of consecutive operational days Dozing distance (m)                          -0.1142      0.072     -1.591      0.112      -0.255       0.027
# Number of consecutive operational days Average temperature during operation (°C)    -0.0691      0.071     -0.969      0.332      -0.209       0.071
# Number of consecutive operational days Type of blade_2                              -0.0067      0.179     -0.037      0.970      -0.358       0.344
# Number of consecutive operational days Type of blade_3                               0.2366      0.181      1.310      0.190      -0.118       0.591
# Number of consecutive operational days Type of blade_4                               0.0383      0.178      0.215      0.830      -0.310       0.387
# Number of consecutive operational days Maximum blade capacity (m³)_6.8              -0.0073      0.177     -0.041      0.967      -0.355       0.341
# Number of consecutive operational days Maximum blade capacity (m³)_8.8              -0.0544      0.175     -0.310      0.756      -0.398       0.289
# Number of consecutive operational days Maximum blade capacity (m³)_11.8              0.0704      0.179      0.393      0.695      -0.281       0.422
# Number of consecutive operational days Ripper used?_1                                0.0247      0.136      0.182      0.856      -0.241       0.291
# Number of consecutive operational days Operation time_2                              0.4419      0.160      2.758      0.006       0.128       0.756
# Number of consecutive operational days Operation time_3                              0.1673      0.162      1.034      0.301      -0.150       0.485
# Ground grade (%)^2                                                                  -0.0530      0.079     -0.667      0.505      -0.209       0.103
# Ground grade (%) Dozing distance (m)                                                -0.0170      0.072     -0.237      0.813      -0.157       0.124
# Ground grade (%) Average temperature during operation (°C)                           0.0182      0.072      0.254      0.799      -0.122       0.159
# Ground grade (%) Type of blade_2                                                     0.1174      0.181      0.650      0.516      -0.237       0.471
# Ground grade (%) Type of blade_3                                                     0.0466      0.181      0.258      0.797      -0.308       0.401
# Ground grade (%) Type of blade_4                                                     0.2740      0.180      1.523      0.128      -0.079       0.627
# Ground grade (%) Maximum blade capacity (m³)_6.8                                    -0.1179      0.178     -0.661      0.508      -0.467       0.232
# Ground grade (%) Maximum blade capacity (m³)_8.8                                    -0.1519      0.177     -0.856      0.392      -0.500       0.196
# Ground grade (%) Maximum blade capacity (m³)_11.8                                   -0.1825      0.178     -1.022      0.307      -0.532       0.167
# Ground grade (%) Ripper used?_1                                                      0.0545      0.137      0.398      0.691      -0.214       0.323
# Ground grade (%) Operation time_2                                                    0.0866      0.163      0.533      0.594      -0.232       0.405
# Ground grade (%) Operation time_3                                                    0.1859      0.159      1.166      0.244      -0.127       0.498
# Dozing distance (m)^2                                                               -0.0377      0.079     -0.475      0.635      -0.193       0.118
# Dozing distance (m) Average temperature during operation (°C)                       -0.0347      0.072     -0.483      0.629      -0.176       0.106
# Dozing distance (m) Type of blade_2                                                  1.6119      0.181      8.929      0.000       1.258       1.966
# Dozing distance (m) Type of blade_3                                                  1.6386      0.179      9.142      0.000       1.287       1.990
# Dozing distance (m) Type of blade_4                                                  1.4812      0.182      8.122      0.000       1.124       1.839
# Dozing distance (m) Maximum blade capacity (m³)_6.8                                  1.7363      0.180      9.651      0.000       1.384       2.089
# Dozing distance (m) Maximum blade capacity (m³)_8.8                                  1.9175      0.179     10.708      0.000       1.566       2.269
# Dozing distance (m) Maximum blade capacity (m³)_11.8                                 1.6122      0.180      8.960      0.000       1.259       1.965
# Dozing distance (m) Ripper used?_1                                                   0.6179      0.137      4.517      0.000       0.350       0.886
# Dozing distance (m) Operation time_2                                                 1.4519      0.162      8.942      0.000       1.134       1.770
# Dozing distance (m) Operation time_3                                                 1.4709      0.160      9.175      0.000       1.157       1.785
# Average temperature during operation (°C)^2                                          0.1257      0.081      1.554      0.120      -0.033       0.284
# Average temperature during operation (°C) Type of blade_2                            0.7694      0.178      4.322      0.000       0.420       1.118
# Average temperature during operation (°C) Type of blade_3                            0.7802      0.180      4.346      0.000       0.428       1.132
# Average temperature during operation (°C) Type of blade_4                            0.5172      0.180      2.872      0.004       0.164       0.870
# Average temperature during operation (°C) Maximum blade capacity (m³)_6.8            0.9448      0.179      5.268      0.000       0.593       1.296
# Average temperature during operation (°C) Maximum blade capacity (m³)_8.8            0.9267      0.176      5.267      0.000       0.582       1.272
# Average temperature during operation (°C) Maximum blade capacity (m³)_11.8           0.9148      0.179      5.115      0.000       0.564       1.265
# Average temperature during operation (°C) Ripper used?_1                             0.0650      0.135      0.480      0.631      -0.201       0.331
# Average temperature during operation (°C) Operation time_2                           0.6766      0.160      4.233      0.000       0.363       0.990
# Average temperature during operation (°C) Operation time_3                           0.7054      0.160      4.406      0.000       0.392       1.019
# Type of blade_2 Type of blade_3                                                  -1.632e-15    3.4e-16     -4.801      0.000    -2.3e-15   -9.65e-16
# Type of blade_2 Type of blade_4                                                   2.011e-15   4.74e-16      4.245      0.000    1.08e-15    2.94e-15
# Type of blade_2 Maximum blade capacity (m³)_6.8                                     -1.7659      0.398     -4.442      0.000      -2.545      -0.986
# Type of blade_2 Maximum blade capacity (m³)_8.8                                     -1.4468      0.385     -3.762      0.000      -2.201      -0.693
# Type of blade_2 Maximum blade capacity (m³)_11.8                                    -1.3187      0.393     -3.357      0.001      -2.089      -0.549
# Type of blade_2 Ripper used?_1                                                       4.3722      0.328     13.347      0.000       3.730       5.014
# Type of blade_2 Operation time_2                                                    -0.6629      0.354     -1.871      0.061      -1.358       0.032
# Type of blade_2 Operation time_3                                                     0.5765      0.356      1.620      0.105      -0.121       1.274
# Type of blade_3 Type of blade_4                                                  -2.008e-15      3e-16     -6.701      0.000    -2.6e-15   -1.42e-15
# Type of blade_3 Maximum blade capacity (m³)_6.8                                     -1.4864      0.392     -3.790      0.000      -2.255      -0.717
# Type of blade_3 Maximum blade capacity (m³)_8.8                                     -1.5074      0.388     -3.884      0.000      -2.268      -0.747
# Type of blade_3 Maximum blade capacity (m³)_11.8                                    -1.4548      0.394     -3.689      0.000      -2.228      -0.682
# Type of blade_3 Ripper used?_1                                                       4.8110      0.317     15.200      0.000       4.190       5.432
# Type of blade_3 Operation time_2                                                     0.8332      0.359      2.322      0.020       0.130       1.537
# Type of blade_3 Operation time_3                                                     1.0321      0.364      2.836      0.005       0.319       1.746
# Type of blade_4 Maximum blade capacity (m³)_6.8                                      0.0898      0.397      0.226      0.821      -0.689       0.868
# Type of blade_4 Maximum blade capacity (m³)_8.8                                     -0.1893      0.390     -0.485      0.627      -0.954       0.576
# Type of blade_4 Maximum blade capacity (m³)_11.8                                     0.2006      0.386      0.520      0.603      -0.556       0.958
# Type of blade_4 Ripper used?_1                                                       4.8279      0.325     14.866      0.000       4.191       5.465
# Type of blade_4 Operation time_2                                                     0.9430      0.352      2.677      0.007       0.252       1.634
# Type of blade_4 Operation time_3                                                     1.1349      0.351      3.231      0.001       0.446       1.824
# Maximum blade capacity (m³)_6.8 Maximum blade capacity (m³)_8.8                   -5.21e-16   8.86e-17     -5.880      0.000   -6.95e-16   -3.47e-16
# Maximum blade capacity (m³)_6.8 Maximum blade capacity (m³)_11.8                  2.226e-16   1.17e-16      1.911      0.056   -5.83e-18    4.51e-16
# Maximum blade capacity (m³)_6.8 Ripper used?_1                                       3.8429      0.316     12.149      0.000       3.223       4.463
# Maximum blade capacity (m³)_6.8 Operation time_2                                    -1.3527      0.362     -3.733      0.000      -2.063      -0.642
# Maximum blade capacity (m³)_6.8 Operation time_3                                    -1.2785      0.361     -3.544      0.000      -1.986      -0.571
# Maximum blade capacity (m³)_8.8 Maximum blade capacity (m³)_11.8                  1.364e-16    4.2e-17      3.250      0.001    5.41e-17    2.19e-16
# Maximum blade capacity (m³)_8.8 Ripper used?_1                                       4.1972      0.312     13.470      0.000       3.586       4.808
# Maximum blade capacity (m³)_8.8 Operation time_2                                    -1.4448      0.350     -4.129      0.000      -2.131      -0.759
# Maximum blade capacity (m³)_8.8 Operation time_3                                    -0.9967      0.355     -2.809      0.005      -1.692      -0.301
# Maximum blade capacity (m³)_11.8 Ripper used?_1                                      4.0588      0.319     12.710      0.000       3.433       4.685
# Maximum blade capacity (m³)_11.8 Operation time_2                                   -1.3019      0.355     -3.669      0.000      -1.998      -0.606
# Maximum blade capacity (m³)_11.8 Operation time_3                                   -0.3096      0.349     -0.887      0.375      -0.994       0.375
# Ripper used?_1 Operation time_2                                                      3.4615      0.288     12.006      0.000       2.896       4.027
# Ripper used?_1 Operation time_3                                                      3.5725      0.291     12.285      0.000       3.002       4.143
# Operation time_2 Operation time_3                                                         0          0        nan        nan           0           0
# ==============================================================================
# Omnibus:                        1.498   Durbin-Watson:                   1.932
# Prob(Omnibus):                  0.473   Jarque-Bera (JB):                1.451
# Skew:                           0.044   Prob(JB):                        0.484
# Kurtosis:                       3.030   Cond. No.                     1.15e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 2.1e-28. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
#                                        OLS Regression Results
# ===================================================================================================
# Dep. Variable:     Actual Measured Productivity (Lm³/Hour)   R-squared:                       0.693
# Model:                                                 OLS   Adj. R-squared:                  0.690
# Method:                                      Least Squares   F-statistic:                     190.0
# Date:                                     Sun, 23 Jun 2024   Prob (F-statistic):               0.00
# Time:                                             15:57:23   Log-Likelihood:                -11614.
# No. Observations:                                     4000   AIC:                         2.332e+04
# Df Residuals:                                         3952   BIC:                         2.363e+04
# Df Model:                                               47
# Covariance Type:                                 nonrobust
# ==============================================================================================================================================
#                                                                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------------------------------------
# const                                                                         39.0107      0.119    327.677      0.000      38.777      39.244
# Total service life time (hours) Maximum blade capacity (m³)_6.8                0.5339      0.156      3.412      0.001       0.227       0.841
# Total service life time (hours) Maximum blade capacity (m³)_8.8                0.3696      0.148      2.498      0.013       0.080       0.660
# Total service life time (hours) Ripper used?_1                                 0.3036      0.116      2.617      0.009       0.076       0.531
# Number of consecutive operational days Operation time_2                        0.5113      0.120      4.263      0.000       0.276       0.746
# Number of consecutive operational days Operation time_3                        0.2458      0.121      2.040      0.041       0.010       0.482
# Ground grade (%) Type of blade_4                                               0.2876      0.139      2.067      0.039       0.015       0.560
# Dozing distance (m) Type of blade_2                                            1.6229      0.179      9.059      0.000       1.272       1.974
# Dozing distance (m) Type of blade_3                                            1.6418      0.178      9.230      0.000       1.293       1.990
# Dozing distance (m) Type of blade_4                                            1.5058      0.181      8.315      0.000       1.151       1.861
# Dozing distance (m) Maximum blade capacity (m³)_6.8                            1.7341      0.178      9.736      0.000       1.385       2.083
# Dozing distance (m) Maximum blade capacity (m³)_8.8                            1.9109      0.178     10.753      0.000       1.562       2.259
# Dozing distance (m) Maximum blade capacity (m³)_11.8                           1.6301      0.179      9.115      0.000       1.279       1.981
# Dozing distance (m) Ripper used?_1                                             0.6014      0.136      4.435      0.000       0.336       0.867
# Dozing distance (m) Operation time_2                                           1.4358      0.161      8.915      0.000       1.120       1.752
# Dozing distance (m) Operation time_3                                           1.4460      0.159      9.090      0.000       1.134       1.758
# Average temperature during operation (°C) Type of blade_2                      0.7537      0.175      4.315      0.000       0.411       1.096
# Average temperature during operation (°C) Type of blade_3                      0.7829      0.176      4.443      0.000       0.437       1.128
# Average temperature during operation (°C) Type of blade_4                      0.5407      0.177      3.047      0.002       0.193       0.889
# Average temperature during operation (°C) Maximum blade capacity (m³)_6.8      0.9489      0.174      5.451      0.000       0.608       1.290
# Average temperature during operation (°C) Maximum blade capacity (m³)_8.8      0.9423      0.172      5.487      0.000       0.606       1.279
# Average temperature during operation (°C) Maximum blade capacity (m³)_11.8     0.9396      0.175      5.371      0.000       0.597       1.282
# Average temperature during operation (°C) Operation time_2                     0.6886      0.157      4.391      0.000       0.381       0.996
# Average temperature during operation (°C) Operation time_3                     0.7154      0.156      4.575      0.000       0.409       1.022
# Type of blade_2 Maximum blade capacity (m³)_6.8                               -1.6267      0.368     -4.418      0.000      -2.349      -0.905
# Type of blade_2 Maximum blade capacity (m³)_8.8                               -1.2343      0.355     -3.476      0.001      -1.930      -0.538
# Type of blade_2 Maximum blade capacity (m³)_11.8                              -1.2891      0.354     -3.643      0.000      -1.983      -0.595
# Type of blade_2 Ripper used?_1                                                 4.5000      0.310     14.535      0.000       3.893       5.107
# Type of blade_2 Operation time_2                                              -0.7847      0.334     -2.352      0.019      -1.439      -0.131
# Type of blade_3 Maximum blade capacity (m³)_6.8                               -1.4908      0.378     -3.946      0.000      -2.231      -0.750
# Type of blade_3 Maximum blade capacity (m³)_8.8                               -1.4371      0.372     -3.867      0.000      -2.166      -0.709
# Type of blade_3 Maximum blade capacity (m³)_11.8                              -1.4826      0.375     -3.953      0.000      -2.218      -0.747
# Type of blade_3 Ripper used?_1                                                 4.8255      0.308     15.671      0.000       4.222       5.429
# Type of blade_3 Operation time_2                                               0.8071      0.355      2.277      0.023       0.112       1.502
# Type of blade_3 Operation time_3                                               0.8723      0.344      2.533      0.011       0.197       1.548
# Type of blade_4 Ripper used?_1                                                 4.8999      0.299     16.413      0.000       4.315       5.485
# Type of blade_4 Operation time_2                                               0.9393      0.326      2.879      0.004       0.300       1.579
# Type of blade_4 Operation time_3                                               0.9420      0.303      3.109      0.002       0.348       1.536
# Maximum blade capacity (m³)_6.8 Ripper used?_1                                 3.7831      0.298     12.678      0.000       3.198       4.368
# Maximum blade capacity (m³)_6.8 Operation time_2                              -1.3457      0.345     -3.898      0.000      -2.022      -0.669
# Maximum blade capacity (m³)_6.8 Operation time_3                              -1.0846      0.327     -3.315      0.001      -1.726      -0.443
# Maximum blade capacity (m³)_8.8 Ripper used?_1                                 4.0630      0.295     13.767      0.000       3.484       4.642
# Maximum blade capacity (m³)_8.8 Operation time_2                              -1.5211      0.333     -4.570      0.000      -2.174      -0.868
# Maximum blade capacity (m³)_8.8 Operation time_3                              -0.8643      0.317     -2.724      0.006      -1.486      -0.242
# Maximum blade capacity (m³)_11.8 Ripper used?_1                                3.9477      0.291     13.563      0.000       3.377       4.518
# Maximum blade capacity (m³)_11.8 Operation time_2                             -1.1807      0.328     -3.605      0.000      -1.823      -0.539
# Ripper used?_1 Operation time_2                                                3.4936      0.272     12.829      0.000       2.960       4.027
# Ripper used?_1 Operation time_3                                                3.6557      0.261     14.014      0.000       3.144       4.167
# Operation time_2 Operation time_3                                                   0          0        nan        nan           0           0
# ==============================================================================
# Omnibus:                        1.372   Durbin-Watson:                   1.935
# Prob(Omnibus):                  0.504   Jarque-Bera (JB):                1.321
# Skew:                           0.041   Prob(JB):                        0.517
# Kurtosis:                       3.034   Cond. No.                     1.13e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 3.99e-29. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# Final Lasso Regression R²: 0.6914
# Final Lasso Regression MSE: 20.4325
