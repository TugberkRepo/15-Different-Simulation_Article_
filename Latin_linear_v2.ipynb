# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import OneHotEncoder, StandardScaler, PolynomialFeatures
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.model_selection import train_test_split, GridSearchCV, cross_val_score
from sklearn.linear_model import Ridge, LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
from statsmodels.stats.outliers_influence import variance_inflation_factor
import statsmodels.api as sm
from pyDOE2 import lhs

# Set random seed for reproducibility
np.random.seed(42)

# Define the ranges and probabilities for each feature
feature_ranges = {
    "Total service life time (hours)": (0, 150000),
    "Service and maintenance condition": ["Good", "Average", "Rather poor", "Poor"],
    "Type of blade": ["Straight tilt dozer", "U-tilt dozer", "Semi U-tilt dozer", "Angle dozer"],
    "Maximum blade capacity (m³)": [4.8, 6.8, 8.8, 11.8],
    "Blade sharpness": ["Good", "Average", "Rather poor", "Poor"],
    "Ripper used?": ["Yes", "No"],
    "Time between gear shifting (seconds)": ["Less than 5", "Between 5~10", "More than 10"],
    "Operator’s skill": ["Good", "Average", "Rather poor", "Poor"],
    "Overall operator’s condition during the operation": ["Good", "Average", "Rather poor", "Poor"],
    "Site management quality": ["Good", "Average", "Rather poor", "Poor"],
    "Number of consecutive operational days": (0, 100),
    "Predominant soil type": ["Sand", "Sandy clay", "Clay", "Gravel", "Broken rocks"],
    "Big pieces of rock exist on the site?": ["No", "Rarely", "Commonly"],
    "Equipment maneuvering space": ["Easy", "Average", "Rather difficult", "Difficult"],
    "Ground grade (%)": (-25, 25),
    "Dozing distance (m)": (0, 150),
    "Operation time": ["Morning", "Afternoon", "Night"],
    "Average temperature during operation (°C)": (-15, 45)
}

# Assign numerical values for categorical data
ordinal_mapping = {
    "Service and maintenance condition": {"Good": 4, "Average": 3, "Rather poor": 2, "Poor": 1},
    "Blade sharpness": {"Good": 4, "Average": 3, "Rather poor": 2, "Poor": 1},
    "Ripper used?": {"Yes": 1, "No": 0},
    "Time between gear shifting (seconds)": {"Less than 5": 3, "Between 5~10": 2, "More than 10": 1},
    "Operator’s skill": {"Good": 4, "Average": 3, "Rather poor": 2, "Poor": 1},
    "Overall operator’s condition during the operation": {"Good": 4, "Average": 3, "Rather poor": 2, "Poor": 1},
    "Site management quality": {"Good": 4, "Average": 3, "Rather poor": 2, "Poor": 1},
    "Predominant soil type": {"Sand": 1, "Sandy clay": 2, "Clay": 3, "Gravel": 4, "Broken rocks": 5},
    "Big pieces of rock exist on the site?": {"No": 1, "Rarely": 2, "Commonly": 3},
    "Equipment maneuvering space": {"Easy": 4, "Average": 3, "Rather difficult": 2, "Difficult": 1},
    "Operation time": {"Morning": 3, "Afternoon": 2, "Night": 1},
    "Type of blade": {"Straight tilt dozer": 1, "U-tilt dozer": 2, "Semi U-tilt dozer": 3, "Angle dozer": 4}
}

# Function to generate dataset using Latin Hypercube Sampling
def generate_lhs_dataset(n_samples):
    data = lhs(len(feature_ranges), samples=n_samples)
    df = pd.DataFrame(data, columns=feature_ranges.keys())

    for feature, value_range in feature_ranges.items():
        if isinstance(value_range, tuple):
            df[feature] = df[feature] * (value_range[1] - value_range[0]) + value_range[0]
        else:
            df[feature] = df[feature].apply(lambda x: np.random.choice(value_range))

    for feature, mapping in ordinal_mapping.items():
        df[feature] = df[feature].map(mapping)
    
    # Add noise to the equation
    def calculate_amp(row):
        noise = np.random.normal(0, 2)
        return (0.00001 * row["Total service life time (hours)"] +
                row["Service and maintenance condition"] +
                row["Type of blade"] +
                0.1 * row["Maximum blade capacity (m³)"] +
                row["Blade sharpness"] +
                10 * row["Ripper used?"] +
                row["Time between gear shifting (seconds)"] +
                row["Operator’s skill"] +
                row["Overall operator’s condition during the operation"] +
                row["Site management quality"] +
                0.01 * row["Number of consecutive operational days"] +
                row["Predominant soil type"] +
                row["Big pieces of rock exist on the site?"] +
                row["Equipment maneuvering space"] +
                0.01 * row["Ground grade (%)"] +
                0.1 * row["Dozing distance (m)"] +
                row["Operation time"] +
                0.1 * row["Average temperature during operation (°C)"] +
                noise)

    df["Actual Measured Productivity (Lm³/Hour)"] = df.apply(calculate_amp, axis=1)
    
    return df

# Generate the dataset
lhs_dataset = generate_lhs_dataset(5000)
print(lhs_dataset.head())

# Define the preprocessing steps
quantitative_columns = [
    "Total service life time (hours)", 
    "Number of consecutive operational days", 
    "Ground grade (%)", 
    "Dozing distance (m)", 
    "Average temperature during operation (°C)"
]

ordinal_columns = [
    "Service and maintenance condition", 
    "Blade sharpness", 
    "Time between gear shifting (seconds)", 
    "Operator’s skill", 
    "Overall operator’s condition during the operation", 
    "Site management quality", 
    "Predominant soil type", 
    "Big pieces of rock exist on the site?", 
    "Equipment maneuvering space"
]

nominal_columns = [
    "Type of blade", 
    "Maximum blade capacity (m³)", 
    "Ripper used?", 
    "Operation time"
]

# Preprocessing pipelines for quantitative and categorical features
numeric_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='median')),
    ('scaler', StandardScaler())
])

nominal_transformer = OneHotEncoder(drop='first')

preprocessor = ColumnTransformer(
    transformers=[
        ('num', numeric_transformer, quantitative_columns),
        ('nom', nominal_transformer, nominal_columns)
    ])

# Apply preprocessing
X = lhs_dataset.drop(columns=['Actual Measured Productivity (Lm³/Hour)'])
y = lhs_dataset['Actual Measured Productivity (Lm³/Hour)']

# Transform features
X_preprocessed = preprocessor.fit_transform(X)

# Add polynomial features
poly = PolynomialFeatures(degree=2, interaction_only=False, include_bias=False)
X_poly = poly.fit_transform(X_preprocessed)

# Get feature names after preprocessing and polynomial transformation
numeric_features = preprocessor.transformers_[0][2]
nominal_features = preprocessor.transformers_[1][1].get_feature_names_out(nominal_columns)
all_features = np.concatenate([numeric_features, nominal_features])
poly_features = poly.get_feature_names_out(all_features)

# Convert to DataFrame
X_poly_df = pd.DataFrame(X_poly, columns=poly_features)

# Ensure data types are correct
X_poly_df = X_poly_df.apply(pd.to_numeric)

# Calculate VIF
X_poly_df_const = sm.add_constant(X_poly_df)  # Add constant term
vif_data = pd.DataFrame()
vif_data["feature"] = X_poly_df_const.columns
vif_data["VIF"] = [variance_inflation_factor(X_poly_df_const.values, i) for i in range(len(X_poly_df_const.columns))]

print(vif_data)

# Drop features with high VIF (typically VIF > 10 indicates high multicollinearity), excluding 'const'
high_vif_features = vif_data[(vif_data["VIF"] > 10) & (vif_data["feature"] != "const")]["feature"].tolist()
X_poly_df_reduced = X_poly_df.drop(columns=high_vif_features)

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_poly_df_reduced, y, test_size=0.2, random_state=42)

# Fit initial linear regression model
initial_lin_reg = LinearRegression()
initial_lin_reg.fit(X_train, y_train)

# Evaluate initial model on test set
initial_y_pred = initial_lin_reg.predict(X_test)
initial_r2 = r2_score(y_test, initial_y_pred)
initial_mse = mean_squared_error(y_test, initial_y_pred)
print(f"Initial Linear Regression R²: {initial_r2:.4f}")
print(f"Initial Linear Regression MSE: {initial_mse:.4f}")

# Perform cross-validation for the initial model
cv_scores = cross_val_score(initial_lin_reg, X_train, y_train, cv=5, scoring='r2')
print(f"Initial Linear Regression CV R²: {np.mean(cv_scores):.4f} ± {np.std(cv_scores):.4f}")

# Fit OLS model for p-value inspection
X_train_const = sm.add_constant(X_train)
ols_model = sm.OLS(y_train, X_train_const).fit()
print(ols_model.summary())

# Iteratively remove features with p-values > 0.05
while True:
    p_values = ols_model.pvalues
    max_p_value = p_values.max()
    if max_p_value > 0.05:
        excluded_feature = p_values.idxmax()
        X_train_const = X_train_const.drop(columns=excluded_feature)
        X_train = X_train.drop(columns=excluded_feature)
        X_test = X_test.drop(columns=excluded_feature)
        ols_model = sm.OLS(y_train, X_train_const).fit()
    else:
        break

print(ols_model.summary())

# Train final linear regression model
final_lin_reg = LinearRegression()
final_lin_reg.fit(X_train, y_train)

# Evaluate final model on test set
final_y_pred = final_lin_reg.predict(X_test)
final_r2 = r2_score(y_test, final_y_pred)
final_mse = mean_squared_error(y_test, final_y_pred)
print(f"Final Linear Regression R²: {final_r2:.4f}")
print(f"Final Linear Regression MSE: {final_mse:.4f}")

# Perform cross-validation for the final model
final_cv_scores = cross_val_score(final_lin_reg, X_train, y_train, cv=5, scoring='r2')
print(f"Final Linear Regression CV R²: {np.mean(final_cv_scores):.4f} ± {np.std(final_cv_scores):.4f}")

# Plot actual vs predicted for final model
plt.figure(figsize=(8, 6))
plt.scatter(y_test, final_y_pred, alpha=0.5)
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'r--')
plt.xlabel('Actual')
plt.ylabel('Predicted')
plt.title('Actual vs Predicted Productivity (Final Model)')
plt.show()

# Plot residuals for final model
final_residuals = y_test - final_y_pred
plt.figure(figsize=(8, 6))
plt.scatter(final_y_pred, final_residuals, alpha=0.5)
plt.hlines(0, xmin=final_y_pred.min(), xmax=final_y_pred.max(), colors='r', linestyles='dashed')
plt.xlabel('Predicted')
plt.ylabel('Residuals')
plt.title('Residuals Plot (Final Model)')
plt.show()
# Out:
#    Total service life time (hours)  Service and maintenance condition  \
# 0                    128682.259420                                  2
# 1                     73516.161762                                  1
# 2                    131367.068316                                  4
# 3                     46277.069667                                  2
# 4                    100543.246141                                  2
#
#    Type of blade  Maximum blade capacity (m³)  Blade sharpness  Ripper used?  \
# 0              3                          8.8                1             1
# 1              3                         11.8                1             0
# 2              3                          8.8                3             0
# 3              3                         11.8                4             0
# 4              4                         11.8                4             1
#
#    Time between gear shifting (seconds)  Operator’s skill  \
# 0                                     1                 2
# 1                                     2                 4
# 2                                     1                 1
# 3                                     3                 2
# 4                                     1                 1
#
#    Overall operator’s condition during the operation  Site management quality  \
# 0                                                  4                        4
# 1                                                  4                        2
# 2                                                  1                        3
# 3                                                  2                        1
# 4                                                  2                        3
#
#    Number of consecutive operational days  Predominant soil type  \
# 0                               49.260481                      4
# 1                               51.722622                      5
# 2                               24.390493                      4
# 3                               48.018537                      1
# 4                               79.708490                      3
#
#    Big pieces of rock exist on the site?  Equipment maneuvering space  \
# 0                                      2                            4
# 1                                      2                            1
# 2                                      2                            3
# 3                                      1                            2
# 4                                      1                            1
#
#    Ground grade (%)  Dozing distance (m)  Operation time  \
# 0        -20.766001            38.405957               3
# 1          8.612879           137.254878               2
# 2         16.455521            49.210053               1
# 3         11.190373            16.359552               2
# 4         -0.767287           136.032657               2
#
#    Average temperature during operation (°C)  \
# 0                                  12.668060
# 1                                  26.717159
# 2                                 -14.492151
# 3                                  41.466129
# 4                                  -6.545569
#
#    Actual Measured Productivity (Lm³/Hour)
# 0                                47.014542
# 1                                49.281523
# 2                                33.243913
# 3                                32.895446
# 4                                49.923794
# C:\Users\tugbe\anaconda3\lib\site-packages\statsmodels\regression\linear_model.py:1736: RuntimeWarning: invalid value encountered in double_scalars
#   return 1 - self.ssr/self.centered_tss
#                                     feature           VIF
# 0                                     const  3.952565e+01
# 1           Total service life time (hours)  9.595811e+00
# 2    Number of consecutive operational days  9.329819e+00
# 3                          Ground grade (%)  9.645216e+00
# 4                       Dozing distance (m)  9.586572e+00
# ..                                      ...           ...
# 115         Ripper used?_1 Operation time_2  3.409207e+00
# 116         Ripper used?_1 Operation time_3  3.445502e+00
# 117                      Operation time_2^2  3.819952e+07
# 118       Operation time_2 Operation time_3           NaN
# 119                      Operation time_3^2  1.275566e+05
#
# [120 rows x 2 columns]
# Initial Linear Regression R²: 0.7025
# Initial Linear Regression MSE: 19.0197
# Initial Linear Regression CV R²: 0.7032 ± 0.0036
#                                        OLS Regression Results
# ===================================================================================================
# Dep. Variable:     Actual Measured Productivity (Lm³/Hour)   R-squared:                       0.719
# Model:                                                 OLS   Adj. R-squared:                  0.712
# Method:                                      Least Squares   F-statistic:                     106.3
# Date:                                     Sun, 23 Jun 2024   Prob (F-statistic):               0.00
# Time:                                             16:26:13   Log-Likelihood:                -11444.
# No. Observations:                                     4000   AIC:                         2.308e+04
# Df Residuals:                                         3905   BIC:                         2.368e+04
# Df Model:                                               94
# Covariance Type:                                 nonrobust
# ====================================================================================================================================================
#                                                                                        coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------------------------------------------
# const                                                                               38.8585      0.209    185.620      0.000      38.448      39.269
# Total service life time (hours)                                                      0.3739      0.208      1.794      0.073      -0.035       0.783
# Number of consecutive operational days                                               0.4169      0.204      2.044      0.041       0.017       0.817
# Ground grade (%)                                                                     0.1738      0.208      0.835      0.404      -0.234       0.582
# Dozing distance (m)                                                                  4.2904      0.207     20.697      0.000       3.884       4.697
# Average temperature during operation (°C)                                            2.0206      0.206      9.828      0.000       1.618       2.424
# Total service life time (hours)^2                                                    0.0221      0.077      0.288      0.774      -0.129       0.173
# Total service life time (hours) Number of consecutive operational days              -0.0141      0.068     -0.205      0.837      -0.148       0.120
# Total service life time (hours) Ground grade (%)                                     0.1814      0.069      2.627      0.009       0.046       0.317
# Total service life time (hours) Dozing distance (m)                                  0.1022      0.069      1.481      0.139      -0.033       0.238
# Total service life time (hours) Average temperature during operation (°C)            0.0240      0.069      0.346      0.729      -0.112       0.160
# Total service life time (hours) Type of blade_2                                      0.0960      0.197      0.488      0.626      -0.290       0.482
# Total service life time (hours) Type of blade_3                                      0.0116      0.195      0.060      0.952      -0.370       0.393
# Total service life time (hours) Type of blade_4                                     -0.1103      0.198     -0.556      0.578      -0.499       0.278
# Total service life time (hours) Maximum blade capacity (m³)_6.8                      0.0746      0.192      0.389      0.697      -0.301       0.450
# Total service life time (hours) Maximum blade capacity (m³)_8.8                      0.1513      0.194      0.781      0.435      -0.228       0.531
# Total service life time (hours) Maximum blade capacity (m³)_11.8                     0.0745      0.196      0.380      0.704      -0.310       0.459
# Total service life time (hours) Ripper used?_1                                      -0.0501      0.139     -0.361      0.718      -0.322       0.222
# Total service life time (hours) Operation time_2                                     0.1604      0.167      0.958      0.338      -0.168       0.489
# Total service life time (hours) Operation time_3                                    -0.0246      0.170     -0.144      0.885      -0.359       0.310
# Number of consecutive operational days^2                                            -0.0568      0.076     -0.745      0.457      -0.206       0.093
# Number of consecutive operational days Ground grade (%)                              0.0565      0.069      0.825      0.409      -0.078       0.191
# Number of consecutive operational days Dozing distance (m)                          -0.0959      0.069     -1.392      0.164      -0.231       0.039
# Number of consecutive operational days Average temperature during operation (°C)     0.0734      0.068      1.080      0.280      -0.060       0.207
# Number of consecutive operational days Type of blade_2                               0.0461      0.195      0.236      0.813      -0.337       0.429
# Number of consecutive operational days Type of blade_3                               0.2010      0.193      1.041      0.298      -0.178       0.580
# Number of consecutive operational days Type of blade_4                              -0.0835      0.195     -0.428      0.668      -0.465       0.298
# Number of consecutive operational days Maximum blade capacity (m³)_6.8              -0.2868      0.190     -1.511      0.131      -0.659       0.085
# Number of consecutive operational days Maximum blade capacity (m³)_8.8              -0.0654      0.192     -0.340      0.734      -0.442       0.311
# Number of consecutive operational days Maximum blade capacity (m³)_11.8             -0.0789      0.191     -0.412      0.680      -0.454       0.296
# Number of consecutive operational days Ripper used?_1                                0.0696      0.137      0.508      0.611      -0.199       0.338
# Number of consecutive operational days Operation time_2                             -0.3306      0.166     -1.990      0.047      -0.656      -0.005
# Number of consecutive operational days Operation time_3                             -0.2211      0.168     -1.316      0.188      -0.550       0.108
# Ground grade (%)^2                                                                  -0.0020      0.077     -0.027      0.979      -0.152       0.148
# Ground grade (%) Dozing distance (m)                                                 0.0124      0.068      0.182      0.856      -0.122       0.146
# Ground grade (%) Average temperature during operation (°C)                          -0.0489      0.069     -0.713      0.476      -0.183       0.086
# Ground grade (%) Type of blade_2                                                    -0.0380      0.191     -0.199      0.843      -0.413       0.337
# Ground grade (%) Type of blade_3                                                    -0.2522      0.195     -1.293      0.196      -0.635       0.130
# Ground grade (%) Type of blade_4                                                    -0.3678      0.195     -1.889      0.059      -0.749       0.014
# Ground grade (%) Maximum blade capacity (m³)_6.8                                     0.2771      0.191      1.450      0.147      -0.097       0.652
# Ground grade (%) Maximum blade capacity (m³)_8.8                                     0.1362      0.196      0.695      0.487      -0.248       0.520
# Ground grade (%) Maximum blade capacity (m³)_11.8                                    0.0231      0.194      0.119      0.905      -0.357       0.403
# Ground grade (%) Ripper used?_1                                                     -0.2179      0.137     -1.587      0.113      -0.487       0.051
# Ground grade (%) Operation time_2                                                    0.2108      0.165      1.275      0.202      -0.113       0.535
# Ground grade (%) Operation time_3                                                    0.2649      0.169      1.569      0.117      -0.066       0.596
# Dozing distance (m)^2                                                               -0.1738      0.077     -2.271      0.023      -0.324      -0.024
# Dozing distance (m) Average temperature during operation (°C)                        0.1371      0.068      2.013      0.044       0.004       0.271
# Dozing distance (m) Type of blade_2                                                  0.0283      0.194      0.146      0.884      -0.351       0.408
# Dozing distance (m) Type of blade_3                                                 -0.2545      0.195     -1.304      0.192      -0.637       0.128
# Dozing distance (m) Type of blade_4                                                 -0.0057      0.195     -0.029      0.977      -0.387       0.376
# Dozing distance (m) Maximum blade capacity (m³)_6.8                                 -0.0270      0.190     -0.142      0.887      -0.400       0.346
# Dozing distance (m) Maximum blade capacity (m³)_8.8                                 -0.0920      0.195     -0.473      0.636      -0.473       0.289
# Dozing distance (m) Maximum blade capacity (m³)_11.8                                -0.1565      0.193     -0.810      0.418      -0.535       0.222
# Dozing distance (m) Ripper used?_1                                                  -0.0070      0.137     -0.051      0.960      -0.276       0.262
# Dozing distance (m) Operation time_2                                                 0.1321      0.167      0.793      0.428      -0.194       0.459
# Dozing distance (m) Operation time_3                                                 0.1341      0.171      0.786      0.432      -0.201       0.469
# Average temperature during operation (°C)^2                                         -0.0290      0.077     -0.376      0.707      -0.180       0.122
# Average temperature during operation (°C) Type of blade_2                            0.0742      0.197      0.377      0.706      -0.311       0.460
# Average temperature during operation (°C) Type of blade_3                           -0.0611      0.190     -0.322      0.748      -0.434       0.311
# Average temperature during operation (°C) Type of blade_4                           -0.1987      0.194     -1.022      0.307      -0.580       0.182
# Average temperature during operation (°C) Maximum blade capacity (m³)_6.8           -0.3224      0.193     -1.668      0.095      -0.701       0.056
# Average temperature during operation (°C) Maximum blade capacity (m³)_8.8           -0.0469      0.192     -0.244      0.807      -0.423       0.329
# Average temperature during operation (°C) Maximum blade capacity (m³)_11.8          -0.3564      0.193     -1.850      0.064      -0.734       0.021
# Average temperature during operation (°C) Ripper used?_1                             0.0010      0.137      0.007      0.994      -0.267       0.269
# Average temperature during operation (°C) Operation time_2                          -0.1335      0.166     -0.805      0.421      -0.458       0.191
# Average temperature during operation (°C) Operation time_3                          -0.0519      0.169     -0.307      0.759      -0.384       0.280
# Type of blade_2 Type of blade_3                                                    2.58e-15   3.24e-16      7.962      0.000    1.94e-15    3.22e-15
# Type of blade_2 Type of blade_4                                                   5.338e-16   3.07e-16      1.738      0.082   -6.84e-17    1.14e-15
# Type of blade_2 Maximum blade capacity (m³)_6.8                                     -1.6763      0.377     -4.451      0.000      -2.415      -0.938
# Type of blade_2 Maximum blade capacity (m³)_8.8                                     -1.2661      0.394     -3.210      0.001      -2.040      -0.493
# Type of blade_2 Maximum blade capacity (m³)_11.8                                    -1.2872      0.385     -3.343      0.001      -2.042      -0.532
# Type of blade_2 Ripper used?_1                                                       4.6110      0.319     14.476      0.000       3.987       5.236
# Type of blade_2 Operation time_2                                                    -0.3632      0.336     -1.082      0.279      -1.021       0.295
# Type of blade_2 Operation time_3                                                     0.2873      0.358      0.802      0.423      -0.415       0.990
# Type of blade_3 Type of blade_4                                                   1.162e-15   2.15e-16      5.394      0.000     7.4e-16    1.58e-15
# Type of blade_3 Maximum blade capacity (m³)_6.8                                     -0.8609      0.371     -2.323      0.020      -1.588      -0.134
# Type of blade_3 Maximum blade capacity (m³)_8.8                                     -0.9634      0.374     -2.574      0.010      -1.697      -0.230
# Type of blade_3 Maximum blade capacity (m³)_11.8                                    -0.2584      0.384     -0.673      0.501      -1.012       0.495
# Type of blade_3 Ripper used?_1                                                       5.0485      0.313     16.152      0.000       4.436       5.661
# Type of blade_3 Operation time_2                                                    -0.2744      0.341     -0.804      0.421      -0.943       0.394
# Type of blade_3 Operation time_3                                                     0.7347      0.362      2.031      0.042       0.026       1.444
# Type of blade_4 Maximum blade capacity (m³)_6.8                                     -0.3341      0.378     -0.884      0.377      -1.075       0.407
# Type of blade_4 Maximum blade capacity (m³)_8.8                                      0.1737      0.376      0.462      0.644      -0.563       0.910
# Type of blade_4 Maximum blade capacity (m³)_11.8                                     0.0453      0.387      0.117      0.907      -0.713       0.803
# Type of blade_4 Ripper used?_1                                                       5.3647      0.315     17.004      0.000       4.746       5.983
# Type of blade_4 Operation time_2                                                     0.1732      0.334      0.518      0.605      -0.483       0.829
# Type of blade_4 Operation time_3                                                     0.8112      0.363      2.232      0.026       0.099       1.524
# Maximum blade capacity (m³)_6.8 Maximum blade capacity (m³)_8.8                   -1.13e-16   1.45e-16     -0.781      0.435   -3.97e-16    1.71e-16
# Maximum blade capacity (m³)_6.8 Maximum blade capacity (m³)_11.8                  4.322e-16   1.28e-16      3.383      0.001    1.82e-16    6.83e-16
# Maximum blade capacity (m³)_6.8 Ripper used?_1                                       3.7169      0.305     12.198      0.000       3.119       4.314
# Maximum blade capacity (m³)_6.8 Operation time_2                                    -0.7223      0.346     -2.087      0.037      -1.401      -0.044
# Maximum blade capacity (m³)_6.8 Operation time_3                                    -0.6392      0.374     -1.707      0.088      -1.373       0.095
# Maximum blade capacity (m³)_8.8 Maximum blade capacity (m³)_11.8                 -2.555e-16   1.01e-16     -2.520      0.012   -4.54e-16   -5.67e-17
# Maximum blade capacity (m³)_8.8 Ripper used?_1                                       3.6221      0.317     11.441      0.000       3.001       4.243
# Maximum blade capacity (m³)_8.8 Operation time_2                                    -0.6788      0.361     -1.878      0.060      -1.387       0.030
# Maximum blade capacity (m³)_8.8 Operation time_3                                    -0.0246      0.357     -0.069      0.945      -0.725       0.676
# Maximum blade capacity (m³)_11.8 Ripper used?_1                                      3.6237      0.316     11.481      0.000       3.005       4.243
# Maximum blade capacity (m³)_11.8 Operation time_2                                   -0.6892      0.362     -1.903      0.057      -1.399       0.021
# Maximum blade capacity (m³)_11.8 Operation time_3                                   -0.1883      0.372     -0.506      0.613      -0.919       0.542
# Ripper used?_1 Operation time_2                                                      3.5654      0.281     12.711      0.000       3.015       4.115
# Ripper used?_1 Operation time_3                                                      3.4092      0.285     11.978      0.000       2.851       3.967
# Operation time_2 Operation time_3                                                         0          0        nan        nan           0           0
# ==============================================================================
# Omnibus:                        1.570   Durbin-Watson:                   2.008
# Prob(Omnibus):                  0.456   Jarque-Bera (JB):                1.616
# Skew:                           0.043   Prob(JB):                        0.446
# Kurtosis:                       2.951   Cond. No.                     1.15e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 2.11e-28. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# C:\Users\tugbe\anaconda3\lib\site-packages\statsmodels\regression\linear_model.py:1918: RuntimeWarning: divide by zero encountered in double_scalars
#   return np.sqrt(eigvals[0]/eigvals[-1])
#                                        OLS Regression Results
# ===================================================================================================
# Dep. Variable:     Actual Measured Productivity (Lm³/Hour)   R-squared:                       0.714
# Model:                                                 OLS   Adj. R-squared:                  0.713
# Method:                                      Least Squares   F-statistic:                     432.2
# Date:                                     Sun, 23 Jun 2024   Prob (F-statistic):               0.00
# Time:                                             16:26:14   Log-Likelihood:                -11476.
# No. Observations:                                     4000   AIC:                         2.300e+04
# Df Residuals:                                         3976   BIC:                         2.315e+04
# Df Model:                                               23
# Covariance Type:                                 nonrobust
# =====================================================================================================================
#                                                         coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------------------------
# const                                                38.8229      0.129    301.676      0.000      38.571      39.075
# Total service life time (hours)                       0.4786      0.068      7.004      0.000       0.345       0.613
# Number of consecutive operational days                0.2097      0.068      3.099      0.002       0.077       0.342
# Ground grade (%)                                      0.1615      0.068      2.388      0.017       0.029       0.294
# Dozing distance (m)                                   4.2617      0.068     62.953      0.000       4.129       4.394
# Average temperature during operation (°C)             1.7292      0.068     25.556      0.000       1.597       1.862
# Total service life time (hours) Ground grade (%)      0.1824      0.068      2.673      0.008       0.049       0.316
# Dozing distance (m)^2                                -0.1746      0.076     -2.301      0.021      -0.323      -0.026
# Type of blade_2 Maximum blade capacity (m³)_6.8      -1.7931      0.332     -5.403      0.000      -2.444      -1.143
# Type of blade_2 Maximum blade capacity (m³)_8.8      -1.2797      0.341     -3.758      0.000      -1.947      -0.612
# Type of blade_2 Maximum blade capacity (m³)_11.8     -1.3077      0.325     -4.021      0.000      -1.945      -0.670
# Type of blade_2 Ripper used?_1                        4.6187      0.286     16.132      0.000       4.057       5.180
# Type of blade_3 Maximum blade capacity (m³)_6.8      -0.8609      0.312     -2.759      0.006      -1.473      -0.249
# Type of blade_3 Maximum blade capacity (m³)_8.8      -0.8596      0.316     -2.722      0.007      -1.479      -0.240
# Type of blade_3 Ripper used?_1                        5.0429      0.267     18.913      0.000       4.520       5.566
# Type of blade_4 Ripper used?_1                        5.6476      0.251     22.490      0.000       5.155       6.140
# Maximum blade capacity (m³)_6.8 Ripper used?_1        3.4660      0.261     13.296      0.000       2.955       3.977
# Maximum blade capacity (m³)_6.8 Operation time_2     -0.7835      0.287     -2.732      0.006      -1.346      -0.221
# Maximum blade capacity (m³)_8.8 Ripper used?_1        3.6044      0.271     13.316      0.000       3.074       4.135
# Maximum blade capacity (m³)_8.8 Operation time_2     -0.8526      0.302     -2.819      0.005      -1.446      -0.260
# Maximum blade capacity (m³)_11.8 Ripper used?_1       3.4834      0.264     13.205      0.000       2.966       4.001
# Maximum blade capacity (m³)_11.8 Operation time_2    -0.8462      0.292     -2.895      0.004      -1.419      -0.273
# Ripper used?_1 Operation time_2                       3.5202      0.251     14.027      0.000       3.028       4.012
# Ripper used?_1 Operation time_3                       3.5966      0.220     16.370      0.000       3.166       4.027
# Operation time_2 Operation time_3                          0          0        nan        nan           0           0
# ==============================================================================
# Omnibus:                        1.466   Durbin-Watson:                   2.011
# Prob(Omnibus):                  0.480   Jarque-Bera (JB):                1.490
# Skew:                           0.046   Prob(JB):                        0.475
# Kurtosis:                       2.978   Cond. No.                          inf
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is      0. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# Final Linear Regression R²: 0.7058
# Final Linear Regression MSE: 18.8080
# Final Linear Regression CV R²: 0.7098 ± 0.0044
