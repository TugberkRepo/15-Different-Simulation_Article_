# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import OneHotEncoder, StandardScaler, PolynomialFeatures
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.linear_model import ElasticNet
from sklearn.metrics import mean_squared_error, r2_score
from statsmodels.stats.outliers_influence import variance_inflation_factor
import statsmodels.api as sm

# Set random seed for reproducibility
np.random.seed(42)

# Define the ranges and probabilities for each feature
feature_ranges = {
    "Total service life time (hours)": (0, 150000),
    "Service and maintenance condition": ["Good", "Average", "Rather poor", "Poor"],
    "Type of blade": ["Straight tilt dozer", "U-tilt dozer", "Semi U-tilt dozer", "Angle dozer"],
    "Maximum blade capacity (m³)": [4.8, 6.8, 8.8, 11.8],
    "Blade sharpness": ["Good", "Average", "Rather poor", "Poor"],
    "Ripper used?": ["Yes", "No"],
    "Time between gear shifting (seconds)": ["Less than 5", "Between 5~10", "More than 10"],
    "Operator’s skill": ["Good", "Average", "Rather poor", "Poor"],
    "Overall operator’s condition during the operation": ["Good", "Average", "Rather poor", "Poor"],
    "Site management quality": ["Good", "Average", "Rather poor", "Poor"],
    "Number of consecutive operational days": (0, 100),
    "Predominant soil type": ["Sand", "Sandy clay", "Clay", "Gravel", "Broken rocks"],
    "Big pieces of rock exist on the site?": ["No", "Rarely", "Commonly"],
    "Equipment maneuvering space": ["Easy", "Average", "Rather difficult", "Difficult"],
    "Ground grade (%)": (-25, 25),
    "Dozing distance (m)": (0, 150),
    "Operation time": ["Morning", "Afternoon", "Night"],
    "Average temperature during operation (°C)": (-15, 45)
}

# Assign numerical values for categorical data
ordinal_mapping = {
    "Service and maintenance condition": {"Good": 4, "Average": 3, "Rather poor": 2, "Poor": 1},
    "Blade sharpness": {"Good": 4, "Average": 3, "Rather poor": 2, "Poor": 1},
    "Ripper used?": {"Yes": 1, "No": 0},
    "Time between gear shifting (seconds)": {"Less than 5": 3, "Between 5~10": 2, "More than 10": 1},
    "Operator’s skill": {"Good": 4, "Average": 3, "Rather poor": 2, "Poor": 1},
    "Overall operator’s condition during the operation": {"Good": 4, "Average": 3, "Rather poor": 2, "Poor": 1},
    "Site management quality": {"Good": 4, "Average": 3, "Rather poor": 2, "Poor": 1},
    "Predominant soil type": {"Sand": 1, "Sandy clay": 2, "Clay": 3, "Gravel": 4, "Broken rocks": 5},
    "Big pieces of rock exist on the site?": {"No": 1, "Rarely": 2, "Commonly": 3},
    "Equipment maneuvering space": {"Easy": 4, "Average": 3, "Rather difficult": 2, "Difficult": 1},
    "Operation time": {"Morning": 3, "Afternoon": 2, "Night": 1},
    "Type of blade": {"Straight tilt dozer": 1, "U-tilt dozer": 2, "Semi U-tilt dozer": 3, "Angle dozer": 4}
}

# Create a function to generate the dataset using Monte Carlo simulation
def generate_dataset(n_samples):
    data = {}
    
    for feature, value_range in feature_ranges.items():
        if isinstance(value_range, tuple):
            if feature in ["Ground grade (%)", "Average temperature during operation (°C)"]:
                data[feature] = np.random.normal((value_range[1] + value_range[0]) / 2, 10, n_samples)
            elif feature == "Dozing distance (m)":
                data[feature] = np.random.poisson(50, n_samples)
            else:
                data[feature] = np.random.uniform(value_range[0], value_range[1], n_samples)
        else:
            data[feature] = np.random.choice(value_range, n_samples)
    
    df = pd.DataFrame(data)
    
    for feature, mapping in ordinal_mapping.items():
        df[feature] = df[feature].map(mapping)
    
    # Use the given sample values to create an equation for AMP and add noise
    def calculate_amp(row):
        noise = np.random.normal(0, 2)
        return (0.00001 * row["Total service life time (hours)"] +
                row["Service and maintenance condition"] +
                row["Type of blade"] +
                0.1 * row["Maximum blade capacity (m³)"] +
                row["Blade sharpness"] +
                10 * row["Ripper used?"] +
                row["Time between gear shifting (seconds)"] +
                row["Operator’s skill"] +
                row["Overall operator’s condition during the operation"] +
                row["Site management quality"] +
                0.01 * row["Number of consecutive operational days"] +
                row["Predominant soil type"] +
                row["Big pieces of rock exist on the site?"] +
                row["Equipment maneuvering space"] +
                0.01 * row["Ground grade (%)"] +
                0.1 * row["Dozing distance (m)"] +
                row["Operation time"] +
                0.1 * row["Average temperature during operation (°C)"] +
                noise)

    df["Actual Measured Productivity (Lm³/Hour)"] = df.apply(calculate_amp, axis=1)
    
    return df

# Generate the dataset
synthetic_dataset = generate_dataset(5000)
print(synthetic_dataset.head())

# Define the preprocessing steps
quantitative_columns = [
    "Total service life time (hours)", 
    "Number of consecutive operational days", 
    "Ground grade (%)", 
    "Dozing distance (m)", 
    "Average temperature during operation (°C)"
]

ordinal_columns = [
    "Service and maintenance condition", 
    "Blade sharpness", 
    "Time between gear shifting (seconds)", 
    "Operator’s skill", 
    "Overall operator’s condition during the operation", 
    "Site management quality", 
    "Predominant soil type", 
    "Big pieces of rock exist on the site?", 
    "Equipment maneuvering space"
]

nominal_columns = [
    "Type of blade", 
    "Maximum blade capacity (m³)", 
    "Ripper used?", 
    "Operation time"
]

# Preprocessing pipelines for quantitative and categorical features
numeric_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='median')),
    ('scaler', StandardScaler())
])

nominal_transformer = OneHotEncoder(drop='first')

preprocessor = ColumnTransformer(
    transformers=[
        ('num', numeric_transformer, quantitative_columns),
        ('nom', nominal_transformer, nominal_columns)
    ])

# Apply preprocessing
X = synthetic_dataset.drop(columns=['Actual Measured Productivity (Lm³/Hour)'])
y = synthetic_dataset['Actual Measured Productivity (Lm³/Hour)']

# Transform features
X_preprocessed = preprocessor.fit_transform(X)

# Add polynomial features
poly = PolynomialFeatures(degree=2, interaction_only=False, include_bias=False)
X_poly = poly.fit_transform(X_preprocessed)

# Get feature names after preprocessing and polynomial transformation
numeric_features = preprocessor.transformers_[0][2]
nominal_features = preprocessor.transformers_[1][1].get_feature_names_out(nominal_columns)
all_features = np.concatenate([numeric_features, nominal_features])
poly_features = poly.get_feature_names_out(all_features)

# Convert to DataFrame
X_poly_df = pd.DataFrame(X_poly, columns=poly_features)

# Ensure data types are correct
X_poly_df = X_poly_df.apply(pd.to_numeric)

# Calculate VIF
X_poly_df_const = sm.add_constant(X_poly_df)  # Add constant term
vif_data = pd.DataFrame()
vif_data["feature"] = X_poly_df_const.columns
vif_data["VIF"] = [variance_inflation_factor(X_poly_df_const.values, i) for i in range(len(X_poly_df_const.columns))]

print(vif_data)

# Drop features with high VIF (typically VIF > 10 indicates high multicollinearity), excluding 'const'
high_vif_features = vif_data[(vif_data["VIF"] > 10) & (vif_data["feature"] != "const")]["feature"].tolist()
X_poly_df_reduced = X_poly_df.drop(columns=high_vif_features)

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_poly_df_reduced, y, test_size=0.2, random_state=42)

# Train Elastic Net regression model with cross-validation to find the best alpha and l1_ratio
elastic_net = ElasticNet(max_iter=100000)
param_grid = {
    'alpha': np.logspace(-4, 4, 9),  # Adjusted range
    'l1_ratio': np.linspace(0.1, 0.9, 9)  # Avoiding extremes
}
elastic_net_cv = GridSearchCV(elastic_net, param_grid, cv=5, scoring='r2')
elastic_net_cv.fit(X_train, y_train)

# Best alpha and l1_ratio
best_params = elastic_net_cv.best_params_
print(f"Best parameters for Elastic Net: {best_params}")

# Train the initial Elastic Net regression model with the best parameters
initial_elastic_net_model = ElasticNet(alpha=best_params['alpha'], l1_ratio=best_params['l1_ratio'], max_iter=100000)
initial_elastic_net_model.fit(X_train, y_train)

# Evaluate the initial model on the test set
initial_y_pred = initial_elastic_net_model.predict(X_test)
initial_r2 = r2_score(y_test, initial_y_pred)
initial_mse = mean_squared_error(y_test, initial_y_pred)
print(f"Initial Elastic Net Regression R²: {initial_r2:.4f}")
print(f"Initial Elastic Net Regression MSE: {initial_mse:.4f}")

# Fit OLS model for p-value inspection
X_train_const = sm.add_constant(X_train)
ols_model = sm.OLS(y_train, X_train_const).fit()
print(ols_model.summary())

# Iteratively remove features with p-values > 0.05
while True:
    p_values = ols_model.pvalues
    max_p_value = p_values.max()
    if max_p_value > 0.05:
        excluded_feature = p_values.idxmax()
        X_train_const = X_train_const.drop(columns=excluded_feature)
        X_train = X_train.drop(columns=excluded_feature)
        X_test = X_test.drop(columns=excluded_feature)
        ols_model = sm.OLS(y_train, X_train_const).fit()
    else:
        break

print(ols_model.summary())

# Train the final Elastic Net regression model
final_elastic_net_model = ElasticNet(alpha=best_params['alpha'], l1_ratio=best_params['l1_ratio'], max_iter=100000)
final_elastic_net_model.fit(X_train, y_train)

# Evaluate the final model on the test set
final_y_pred = final_elastic_net_model.predict(X_test)
final_r2 = r2_score(y_test, final_y_pred)
final_mse = mean_squared_error(y_test, final_y_pred)
print(f"Final Elastic Net Regression R²: {final_r2:.4f}")
print(f"Final Elastic Net Regression MSE: {final_mse:.4f}")

# Plot actual vs predicted for final model
plt.figure(figsize=(8, 6))
plt.scatter(y_test, final_y_pred, alpha=0.5)
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'r--')
plt.xlabel('Actual')
plt.ylabel('Predicted')
plt.title('Actual vs Predicted Productivity (Final Elastic Net Model)')
plt.show()

# Plot residuals for final model
final_residuals = y_test - final_y_pred
plt.figure(figsize=(8, 6))
plt.scatter(final_y_pred, final_residuals, alpha=0.5)
plt.hlines(0, xmin=final_y_pred.min(), xmax=final_y_pred.max(), colors='r', linestyles='dashed')
plt.xlabel('Predicted')
plt.ylabel('Residuals')
plt.title('Residuals Plot (Final Elastic Net Model)')
plt.show()
# Out:
#    Total service life time (hours)  Service and maintenance condition  \
# 0                     56181.017827                                  2
# 1                    142607.145961                                  1
# 2                    109799.091272                                  2
# 3                     89798.772630                                  1
# 4                     23402.796066                                  1
#
#    Type of blade  Maximum blade capacity (m³)  Blade sharpness  Ripper used?  \
# 0              4                          8.8                2             0
# 1              4                         11.8                3             0
# 2              2                         11.8                2             1
# 3              1                          6.8                1             0
# 4              1                          4.8                1             1
#
#    Time between gear shifting (seconds)  Operator’s skill  \
# 0                                     3                 4
# 1                                     2                 2
# 2                                     2                 2
# 3                                     2                 4
# 4                                     2                 2
#
#    Overall operator’s condition during the operation  Site management quality  \
# 0                                                  4                        4
# 1                                                  4                        2
# 2                                                  4                        4
# 3                                                  2                        2
# 4                                                  2                        3
#
#    Number of consecutive operational days  Predominant soil type  \
# 0                               78.167267                      3
# 1                               37.624005                      2
# 2                               43.274158                      5
# 3                               36.162490                      1
# 4                               31.565072                      4
#
#    Big pieces of rock exist on the site?  Equipment maneuvering space  \
# 0                                      2                            1
# 1                                      2                            4
# 2                                      3                            3
# 3                                      3                            2
# 4                                      3                            4
#
#    Ground grade (%)  Dozing distance (m)  Operation time  \
# 0         -8.393080                   54               3
# 1         -0.854197                   46               1
# 2        -16.073089                   52               3
# 3         -9.707052                   60               1
# 4         -2.758468                   40               2
#
#    Average temperature during operation (°C)  \
# 0                                  21.908717
# 1                                   9.391094
# 2                                  23.008523
# 3                                  15.878867
# 4                                  17.879739
#
#    Actual Measured Productivity (Lm³/Hour)
# 0                                43.103554
# 1                                33.673984
# 2                                51.927967
# 3                                28.341914
# 4                                40.174685
# C:\Users\tugbe\anaconda3\lib\site-packages\statsmodels\regression\linear_model.py:1736: RuntimeWarning: invalid value encountered in double_scalars
#   return 1 - self.ssr/self.centered_tss
#                                     feature           VIF
# 0                                     const  4.537589e+01
# 1           Total service life time (hours)  1.031622e+01
# 2    Number of consecutive operational days  1.059593e+01
# 3                          Ground grade (%)  1.064028e+01
# 4                       Dozing distance (m)  1.089063e+01
# ..                                      ...           ...
# 115         Ripper used?_1 Operation time_2  3.471276e+00
# 116         Ripper used?_1 Operation time_3  3.339629e+00
# 117                      Operation time_2^2  2.761832e+07
# 118       Operation time_2 Operation time_3           NaN
# 119                      Operation time_3^2  7.026755e+04
#
# [120 rows x 2 columns]
# Best parameters for Elastic Net: {'alpha': 0.01, 'l1_ratio': 0.9}
# Initial Elastic Net Regression R²: 0.5929
# Initial Elastic Net Regression MSE: 17.2864
#                                        OLS Regression Results
# ===================================================================================================
# Dep. Variable:     Actual Measured Productivity (Lm³/Hour)   R-squared:                       0.595
# Model:                                                 OLS   Adj. R-squared:                  0.585
# Method:                                      Least Squares   F-statistic:                     64.47
# Date:                                     Sun, 23 Jun 2024   Prob (F-statistic):               0.00
# Time:                                             16:09:00   Log-Likelihood:                -11406.
# No. Observations:                                     4000   AIC:                         2.299e+04
# Df Residuals:                                         3910   BIC:                         2.356e+04
# Df Model:                                               89
# Covariance Type:                                 nonrobust
# ====================================================================================================================================================
#                                                                                        coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------------------------------------------
# const                                                                               36.3468      0.178    204.166      0.000      35.998      36.696
# Total service life time (hours)^2                                                    0.0283      0.076      0.371      0.711      -0.121       0.178
# Total service life time (hours) Number of consecutive operational days               0.0666      0.068      0.980      0.327      -0.067       0.200
# Total service life time (hours) Ground grade (%)                                    -0.0347      0.066     -0.524      0.600      -0.165       0.095
# Total service life time (hours) Dozing distance (m)                                  0.1347      0.068      1.990      0.047       0.002       0.267
# Total service life time (hours) Average temperature during operation (°C)            0.0874      0.067      1.298      0.194      -0.045       0.219
# Total service life time (hours) Type of blade_2                                      0.0880      0.169      0.521      0.603      -0.243       0.419
# Total service life time (hours) Type of blade_3                                      0.1232      0.170      0.726      0.468      -0.209       0.456
# Total service life time (hours) Type of blade_4                                     -0.0080      0.169     -0.047      0.962      -0.339       0.323
# Total service life time (hours) Maximum blade capacity (m³)_6.8                      0.4159      0.172      2.415      0.016       0.078       0.754
# Total service life time (hours) Maximum blade capacity (m³)_8.8                      0.2223      0.168      1.325      0.185      -0.107       0.551
# Total service life time (hours) Maximum blade capacity (m³)_11.8                     0.1542      0.168      0.921      0.357      -0.174       0.483
# Total service life time (hours) Ripper used?_1                                       0.0167      0.129      0.129      0.897      -0.237       0.270
# Total service life time (hours) Operation time_2                                     0.2001      0.153      1.306      0.191      -0.100       0.500
# Total service life time (hours) Operation time_3                                     0.0506      0.153      0.330      0.741      -0.250       0.351
# Number of consecutive operational days^2                                            -0.0210      0.075     -0.278      0.781      -0.169       0.127
# Number of consecutive operational days Ground grade (%)                              0.0548      0.067      0.815      0.415      -0.077       0.187
# Number of consecutive operational days Dozing distance (m)                          -0.0622      0.069     -0.896      0.371      -0.198       0.074
# Number of consecutive operational days Average temperature during operation (°C)    -0.0227      0.068     -0.336      0.737      -0.155       0.110
# Number of consecutive operational days Type of blade_2                               0.1448      0.166      0.871      0.384      -0.181       0.471
# Number of consecutive operational days Type of blade_3                               0.3146      0.171      1.837      0.066      -0.021       0.650
# Number of consecutive operational days Type of blade_4                               0.1538      0.168      0.914      0.361      -0.176       0.484
# Number of consecutive operational days Maximum blade capacity (m³)_6.8              -0.0373      0.170     -0.219      0.827      -0.371       0.297
# Number of consecutive operational days Maximum blade capacity (m³)_8.8               0.0054      0.169      0.032      0.974      -0.326       0.337
# Number of consecutive operational days Maximum blade capacity (m³)_11.8              0.1692      0.172      0.985      0.325      -0.168       0.506
# Number of consecutive operational days Ripper used?_1                               -0.1620      0.129     -1.260      0.208      -0.414       0.090
# Number of consecutive operational days Operation time_2                              0.1768      0.152      1.162      0.245      -0.122       0.475
# Number of consecutive operational days Operation time_3                              0.2264      0.153      1.483      0.138      -0.073       0.526
# Ground grade (%)^2                                                                   0.0447      0.046      0.970      0.332      -0.046       0.135
# Ground grade (%) Dozing distance (m)                                                -0.0349      0.067     -0.523      0.601      -0.166       0.096
# Ground grade (%) Average temperature during operation (°C)                           0.0828      0.066      1.261      0.208      -0.046       0.212
# Ground grade (%) Type of blade_2                                                     0.1328      0.174      0.764      0.445      -0.208       0.473
# Ground grade (%) Type of blade_3                                                    -0.1077      0.172     -0.626      0.531      -0.445       0.230
# Ground grade (%) Type of blade_4                                                    -0.0602      0.166     -0.362      0.718      -0.387       0.266
# Ground grade (%) Maximum blade capacity (m³)_6.8                                     0.1026      0.169      0.607      0.544      -0.229       0.434
# Ground grade (%) Maximum blade capacity (m³)_8.8                                     0.0901      0.172      0.524      0.601      -0.247       0.427
# Ground grade (%) Maximum blade capacity (m³)_11.8                                    0.2051      0.174      1.180      0.238      -0.136       0.546
# Ground grade (%) Ripper used?_1                                                      0.1241      0.128      0.968      0.333      -0.127       0.375
# Ground grade (%) Operation time_2                                                    0.0368      0.153      0.240      0.810      -0.264       0.337
# Ground grade (%) Operation time_3                                                   -0.0597      0.153     -0.391      0.696      -0.359       0.240
# Dozing distance (m)^2                                                                0.0368      0.049      0.752      0.452      -0.059       0.133
# Dozing distance (m) Average temperature during operation (°C)                        0.0735      0.068      1.075      0.283      -0.061       0.208
# Dozing distance (m) Type of blade_2                                                  0.2680      0.172      1.560      0.119      -0.069       0.605
# Dozing distance (m) Type of blade_3                                                  0.3873      0.175      2.213      0.027       0.044       0.730
# Dozing distance (m) Type of blade_4                                                  0.2296      0.170      1.354      0.176      -0.103       0.562
# Dozing distance (m) Maximum blade capacity (m³)_6.8                                 -0.0384      0.172     -0.224      0.823      -0.375       0.298
# Dozing distance (m) Maximum blade capacity (m³)_8.8                                  0.0909      0.171      0.533      0.594      -0.244       0.426
# Dozing distance (m) Maximum blade capacity (m³)_11.8                                 0.3702      0.174      2.126      0.034       0.029       0.712
# Dozing distance (m) Ripper used?_1                                                   0.1124      0.130      0.865      0.387      -0.142       0.367
# Dozing distance (m) Operation time_2                                                 0.4062      0.154      2.644      0.008       0.105       0.708
# Dozing distance (m) Operation time_3                                                 0.3637      0.153      2.384      0.017       0.065       0.663
# Average temperature during operation (°C)^2                                         -0.0168      0.048     -0.350      0.727      -0.111       0.077
# Average temperature during operation (°C) Type of blade_2                            0.4152      0.174      2.393      0.017       0.075       0.755
# Average temperature during operation (°C) Type of blade_3                            0.1823      0.173      1.052      0.293      -0.158       0.522
# Average temperature during operation (°C) Type of blade_4                            0.2994      0.166      1.804      0.071      -0.026       0.625
# Average temperature during operation (°C) Maximum blade capacity (m³)_6.8            0.3197      0.168      1.901      0.057      -0.010       0.649
# Average temperature during operation (°C) Maximum blade capacity (m³)_8.8            0.4927      0.170      2.902      0.004       0.160       0.826
# Average temperature during operation (°C) Maximum blade capacity (m³)_11.8           0.3060      0.167      1.838      0.066      -0.020       0.633
# Average temperature during operation (°C) Ripper used?_1                             0.0913      0.131      0.697      0.486      -0.165       0.348
# Average temperature during operation (°C) Operation time_2                           0.3024      0.151      1.999      0.046       0.006       0.599
# Average temperature during operation (°C) Operation time_3                           0.6374      0.155      4.125      0.000       0.334       0.940
# Type of blade_2 Type of blade_3                                                   -1.94e-15   2.99e-16     -6.494      0.000   -2.53e-15   -1.35e-15
# Type of blade_2 Type of blade_4                                                   7.899e-16   3.28e-16      2.411      0.016    1.48e-16    1.43e-15
# Type of blade_2 Maximum blade capacity (m³)_6.8                                     -1.8305      0.375     -4.880      0.000      -2.566      -1.095
# Type of blade_2 Maximum blade capacity (m³)_8.8                                     -1.2042      0.368     -3.275      0.001      -1.925      -0.483
# Type of blade_2 Maximum blade capacity (m³)_11.8                                    -0.8742      0.371     -2.354      0.019      -1.602      -0.146
# Type of blade_2 Ripper used?_1                                                       4.5058      0.308     14.650      0.000       3.903       5.109
# Type of blade_2 Operation time_2                                                    -0.4074      0.346     -1.177      0.239      -1.086       0.271
# Type of blade_2 Operation time_3                                                    -0.2069      0.341     -0.607      0.544      -0.875       0.461
# Type of blade_3 Type of blade_4                                                   2.184e-16   2.92e-16      0.748      0.455   -3.54e-16    7.91e-16
# Type of blade_3 Maximum blade capacity (m³)_6.8                                     -1.2844      0.370     -3.471      0.001      -2.010      -0.559
# Type of blade_3 Maximum blade capacity (m³)_8.8                                     -1.3969      0.375     -3.722      0.000      -2.133      -0.661
# Type of blade_3 Maximum blade capacity (m³)_11.8                                    -0.9990      0.384     -2.600      0.009      -1.752      -0.246
# Type of blade_3 Ripper used?_1                                                       4.9865      0.305     16.354      0.000       4.389       5.584
# Type of blade_3 Operation time_2                                                     0.2712      0.345      0.786      0.432      -0.405       0.948
# Type of blade_3 Operation time_3                                                     0.4775      0.357      1.337      0.181      -0.223       1.178
# Type of blade_4 Maximum blade capacity (m³)_6.8                                      0.2018      0.382      0.528      0.598      -0.548       0.951
# Type of blade_4 Maximum blade capacity (m³)_8.8                                     -0.3497      0.374     -0.934      0.350      -1.084       0.384
# Type of blade_4 Maximum blade capacity (m³)_11.8                                     0.5934      0.362      1.637      0.102      -0.117       1.304
# Type of blade_4 Ripper used?_1                                                       5.0535      0.305     16.550      0.000       4.455       5.652
# Type of blade_4 Operation time_2                                                     0.3168      0.341      0.928      0.353      -0.353       0.986
# Type of blade_4 Operation time_3                                                     0.6392      0.330      1.934      0.053      -0.009       1.287
# Maximum blade capacity (m³)_6.8 Maximum blade capacity (m³)_8.8                   1.994e-17   7.02e-17      0.284      0.776   -1.18e-16    1.58e-16
# Maximum blade capacity (m³)_6.8 Maximum blade capacity (m³)_11.8                 -3.511e-17   5.13e-17     -0.684      0.494   -1.36e-16    6.56e-17
# Maximum blade capacity (m³)_6.8 Ripper used?_1                                       3.4811      0.305     11.419      0.000       2.883       4.079
# Maximum blade capacity (m³)_6.8 Operation time_2                                    -1.0211      0.338     -3.017      0.003      -1.685      -0.357
# Maximum blade capacity (m³)_6.8 Operation time_3                                    -0.6846      0.342     -2.002      0.045      -1.355      -0.014
# Maximum blade capacity (m³)_8.8 Maximum blade capacity (m³)_11.8                 -5.691e-16   4.28e-17    -13.295      0.000   -6.53e-16   -4.85e-16
# Maximum blade capacity (m³)_8.8 Ripper used?_1                                       3.7440      0.305     12.287      0.000       3.147       4.341
# Maximum blade capacity (m³)_8.8 Operation time_2                                    -0.7735      0.344     -2.249      0.025      -1.448      -0.099
# Maximum blade capacity (m³)_8.8 Operation time_3                                    -0.5009      0.327     -1.531      0.126      -1.142       0.141
# Maximum blade capacity (m³)_11.8 Ripper used?_1                                      4.0327      0.311     12.983      0.000       3.424       4.642
# Maximum blade capacity (m³)_11.8 Operation time_2                                   -1.3156      0.342     -3.850      0.000      -1.986      -0.646
# Maximum blade capacity (m³)_11.8 Operation time_3                                   -0.8059      0.348     -2.316      0.021      -1.488      -0.124
# Ripper used?_1 Operation time_2                                                      3.3694      0.273     12.351      0.000       2.835       3.904
# Ripper used?_1 Operation time_3                                                      4.0417      0.282     14.323      0.000       3.488       4.595
# Operation time_2 Operation time_3                                                         0          0        nan        nan           0           0
# ==============================================================================
# Omnibus:                        1.483   Durbin-Watson:                   1.969
# Prob(Omnibus):                  0.476   Jarque-Bera (JB):                1.433
# Skew:                           0.026   Prob(JB):                        0.489
# Kurtosis:                       3.076   Cond. No.                     1.21e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 2.12e-28. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
#                                        OLS Regression Results
# ===================================================================================================
# Dep. Variable:     Actual Measured Productivity (Lm³/Hour)   R-squared:                       0.589
# Model:                                                 OLS   Adj. R-squared:                  0.586
# Method:                                      Least Squares   F-statistic:                     167.3
# Date:                                     Sun, 23 Jun 2024   Prob (F-statistic):               0.00
# Time:                                             16:09:01   Log-Likelihood:                -11433.
# No. Observations:                                     4000   AIC:                         2.294e+04
# Df Residuals:                                         3965   BIC:                         2.316e+04
# Df Model:                                               34
# Covariance Type:                                 nonrobust
# ==============================================================================================================================================
#                                                                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------------------------------------
# const                                                                         36.3637      0.107    338.974      0.000      36.153      36.574
# Total service life time (hours) Dozing distance (m)                            0.1424      0.067      2.126      0.034       0.011       0.274
# Total service life time (hours) Maximum blade capacity (m³)_6.8                0.5484      0.138      3.977      0.000       0.278       0.819
# Total service life time (hours) Maximum blade capacity (m³)_8.8                0.3706      0.132      2.815      0.005       0.112       0.629
# Total service life time (hours) Maximum blade capacity (m³)_11.8               0.3238      0.131      2.470      0.014       0.067       0.581
# Number of consecutive operational days Operation time_2                        0.2925      0.117      2.497      0.013       0.063       0.522
# Number of consecutive operational days Operation time_3                        0.3069      0.117      2.617      0.009       0.077       0.537
# Ground grade (%) Type of blade_2                                               0.2956      0.135      2.186      0.029       0.031       0.561
# Dozing distance (m) Type of blade_3                                            0.3266      0.154      2.115      0.035       0.024       0.629
# Dozing distance (m) Maximum blade capacity (m³)_11.8                           0.4292      0.149      2.875      0.004       0.136       0.722
# Dozing distance (m) Operation time_2                                           0.6089      0.124      4.918      0.000       0.366       0.852
# Dozing distance (m) Operation time_3                                           0.5375      0.124      4.331      0.000       0.294       0.781
# Average temperature during operation (°C) Maximum blade capacity (m³)_6.8      0.4802      0.153      3.131      0.002       0.180       0.781
# Average temperature during operation (°C) Maximum blade capacity (m³)_8.8      0.6655      0.155      4.307      0.000       0.363       0.968
# Average temperature during operation (°C) Maximum blade capacity (m³)_11.8     0.4790      0.151      3.182      0.001       0.184       0.774
# Average temperature during operation (°C) Operation time_2                     0.4452      0.140      3.187      0.001       0.171       0.719
# Average temperature during operation (°C) Operation time_3                     0.7401      0.143      5.168      0.000       0.459       1.021
# Type of blade_2 Maximum blade capacity (m³)_6.8                               -2.2289      0.330     -6.755      0.000      -2.876      -1.582
# Type of blade_2 Maximum blade capacity (m³)_8.8                               -1.5111      0.319     -4.740      0.000      -2.136      -0.886
# Type of blade_2 Maximum blade capacity (m³)_11.8                              -1.2108      0.341     -3.549      0.000      -1.880      -0.542
# Type of blade_2 Ripper used?_1                                                 4.6237      0.279     16.545      0.000       4.076       5.172
# Type of blade_3 Maximum blade capacity (m³)_6.8                               -1.3223      0.333     -3.969      0.000      -1.976      -0.669
# Type of blade_3 Maximum blade capacity (m³)_8.8                               -1.2685      0.325     -3.900      0.000      -1.906      -0.631
# Type of blade_3 Maximum blade capacity (m³)_11.8                              -0.9564      0.342     -2.797      0.005      -1.627      -0.286
# Type of blade_3 Ripper used?_1                                                 5.2557      0.277     18.997      0.000       4.713       5.798
# Type of blade_4 Maximum blade capacity (m³)_11.8                               0.6190      0.315      1.967      0.049       0.002       1.236
# Type of blade_4 Ripper used?_1                                                 5.3763      0.254     21.183      0.000       4.879       5.874
# Maximum blade capacity (m³)_6.8 Ripper used?_1                                 3.3310      0.262     12.701      0.000       2.817       3.845
# Maximum blade capacity (m³)_6.8 Operation time_2                              -0.7457      0.292     -2.551      0.011      -1.319      -0.173
# Maximum blade capacity (m³)_8.8 Ripper used?_1                                 3.5723      0.265     13.496      0.000       3.053       4.091
# Maximum blade capacity (m³)_8.8 Operation time_2                              -0.7177      0.288     -2.490      0.013      -1.283      -0.153
# Maximum blade capacity (m³)_11.8 Ripper used?_1                                3.7934      0.278     13.634      0.000       3.248       4.339
# Maximum blade capacity (m³)_11.8 Operation time_2                             -1.0982      0.296     -3.711      0.000      -1.678      -0.518
# Ripper used?_1 Operation time_2                                                3.3446      0.249     13.409      0.000       2.856       3.834
# Ripper used?_1 Operation time_3                                                3.8077      0.223     17.072      0.000       3.370       4.245
# Operation time_2 Operation time_3                                                   0          0        nan        nan           0           0
# ==============================================================================
# Omnibus:                        1.570   Durbin-Watson:                   1.969
# Prob(Omnibus):                  0.456   Jarque-Bera (JB):                1.507
# Skew:                           0.039   Prob(JB):                        0.471
# Kurtosis:                       3.056   Cond. No.                     1.11e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 3.99e-29. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# Final Elastic Net Regression R²: 0.5891
# Final Elastic Net Regression MSE: 17.4487
