# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import OneHotEncoder, StandardScaler, PolynomialFeatures
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.model_selection import train_test_split, GridSearchCV, cross_val_score
from sklearn.linear_model import ElasticNet
from sklearn.metrics import mean_squared_error, r2_score
from statsmodels.stats.outliers_influence import variance_inflation_factor
import statsmodels.api as sm
from pyDOE2 import lhs

# Set random seed for reproducibility
np.random.seed(42)

# Define the ranges and probabilities for each feature
feature_ranges = {
    "Total service life time (hours)": (0, 150000),
    "Service and maintenance condition": ["Good", "Average", "Rather poor", "Poor"],
    "Type of blade": ["Straight tilt dozer", "U-tilt dozer", "Semi U-tilt dozer", "Angle dozer"],
    "Maximum blade capacity (m³)": [4.8, 6.8, 8.8, 11.8],
    "Blade sharpness": ["Good", "Average", "Rather poor", "Poor"],
    "Ripper used?": ["Yes", "No"],
    "Time between gear shifting (seconds)": ["Less than 5", "Between 5~10", "More than 10"],
    "Operator’s skill": ["Good", "Average", "Rather poor", "Poor"],
    "Overall operator’s condition during the operation": ["Good", "Average", "Rather poor", "Poor"],
    "Site management quality": ["Good", "Average", "Rather poor", "Poor"],
    "Number of consecutive operational days": (0, 100),
    "Predominant soil type": ["Sand", "Sandy clay", "Clay", "Gravel", "Broken rocks"],
    "Big pieces of rock exist on the site?": ["No", "Rarely", "Commonly"],
    "Equipment maneuvering space": ["Easy", "Average", "Rather difficult", "Difficult"],
    "Ground grade (%)": (-25, 25),
    "Dozing distance (m)": (0, 150),
    "Operation time": ["Morning", "Afternoon", "Night"],
    "Average temperature during operation (°C)": (-15, 45)
}

# Assign numerical values for categorical data
ordinal_mapping = {
    "Service and maintenance condition": {"Good": 4, "Average": 3, "Rather poor": 2, "Poor": 1},
    "Blade sharpness": {"Good": 4, "Average": 3, "Rather poor": 2, "Poor": 1},
    "Ripper used?": {"Yes": 1, "No": 0},
    "Time between gear shifting (seconds)": {"Less than 5": 3, "Between 5~10": 2, "More than 10": 1},
    "Operator’s skill": {"Good": 4, "Average": 3, "Rather poor": 2, "Poor": 1},
    "Overall operator’s condition during the operation": {"Good": 4, "Average": 3, "Rather poor": 2, "Poor": 1},
    "Site management quality": {"Good": 4, "Average": 3, "Rather poor": 2, "Poor": 1},
    "Predominant soil type": {"Sand": 1, "Sandy clay": 2, "Clay": 3, "Gravel": 4, "Broken rocks": 5},
    "Big pieces of rock exist on the site?": {"No": 1, "Rarely": 2, "Commonly": 3},
    "Equipment maneuvering space": {"Easy": 4, "Average": 3, "Rather difficult": 2, "Difficult": 1},
    "Operation time": {"Morning": 3, "Afternoon": 2, "Night": 1},
    "Type of blade": {"Straight tilt dozer": 1, "U-tilt dozer": 2, "Semi U-tilt dozer": 3, "Angle dozer": 4}
}

# Function to generate dataset using Latin Hypercube Sampling
def generate_lhs_dataset(n_samples):
    data = lhs(len(feature_ranges), samples=n_samples)
    df = pd.DataFrame(data, columns=feature_ranges.keys())

    for feature, value_range in feature_ranges.items():
        if isinstance(value_range, tuple):
            df[feature] = df[feature] * (value_range[1] - value_range[0]) + value_range[0]
        else:
            df[feature] = df[feature].apply(lambda x: np.random.choice(value_range))

    for feature, mapping in ordinal_mapping.items():
        df[feature] = df[feature].map(mapping)
    
    # Add noise to the equation
    def calculate_amp(row):
        noise = np.random.normal(0, 2)
        return (0.00001 * row["Total service life time (hours)"] +
                row["Service and maintenance condition"] +
                row["Type of blade"] +
                0.1 * row["Maximum blade capacity (m³)"] +
                row["Blade sharpness"] +
                10 * row["Ripper used?"] +
                row["Time between gear shifting (seconds)"] +
                row["Operator’s skill"] +
                row["Overall operator’s condition during the operation"] +
                row["Site management quality"] +
                0.01 * row["Number of consecutive operational days"] +
                row["Predominant soil type"] +
                row["Big pieces of rock exist on the site?"] +
                row["Equipment maneuvering space"] +
                0.01 * row["Ground grade (%)"] +
                0.1 * row["Dozing distance (m)"] +
                row["Operation time"] +
                0.1 * row["Average temperature during operation (°C)"] +
                noise)

    df["Actual Measured Productivity (Lm³/Hour)"] = df.apply(calculate_amp, axis=1)
    
    return df

# Generate the dataset
lhs_dataset = generate_lhs_dataset(5000)
print(lhs_dataset.head())

# Define the preprocessing steps
quantitative_columns = [
    "Total service life time (hours)", 
    "Number of consecutive operational days", 
    "Ground grade (%)", 
    "Dozing distance (m)", 
    "Average temperature during operation (°C)"
]

ordinal_columns = [
    "Service and maintenance condition", 
    "Blade sharpness", 
    "Time between gear shifting (seconds)", 
    "Operator’s skill", 
    "Overall operator’s condition during the operation", 
    "Site management quality", 
    "Predominant soil type", 
    "Big pieces of rock exist on the site?", 
    "Equipment maneuvering space"
]

nominal_columns = [
    "Type of blade", 
    "Maximum blade capacity (m³)", 
    "Ripper used?", 
    "Operation time"
]

# Preprocessing pipelines for quantitative and categorical features
numeric_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='median')),
    ('scaler', StandardScaler())
])

nominal_transformer = OneHotEncoder(drop='first')

preprocessor = ColumnTransformer(
    transformers=[
        ('num', numeric_transformer, quantitative_columns),
        ('nom', nominal_transformer, nominal_columns)
    ])

# Apply preprocessing
X = lhs_dataset.drop(columns=['Actual Measured Productivity (Lm³/Hour)'])
y = lhs_dataset['Actual Measured Productivity (Lm³/Hour)']

# Transform features
X_preprocessed = preprocessor.fit_transform(X)

# Add polynomial features
poly = PolynomialFeatures(degree=2, interaction_only=False, include_bias=False)
X_poly = poly.fit_transform(X_preprocessed)

# Get feature names after preprocessing and polynomial transformation
numeric_features = preprocessor.transformers_[0][2]
nominal_features = preprocessor.transformers_[1][1].get_feature_names_out(nominal_columns)
all_features = np.concatenate([numeric_features, nominal_features])
poly_features = poly.get_feature_names_out(all_features)

# Convert to DataFrame
X_poly_df = pd.DataFrame(X_poly, columns=poly_features)

# Ensure data types are correct
X_poly_df = X_poly_df.apply(pd.to_numeric)

# Calculate VIF
X_poly_df_const = sm.add_constant(X_poly_df)  # Add constant term
vif_data = pd.DataFrame()
vif_data["feature"] = X_poly_df_const.columns
vif_data["VIF"] = [variance_inflation_factor(X_poly_df_const.values, i) for i in range(len(X_poly_df_const.columns))]

print(vif_data)

# Drop features with high VIF (typically VIF > 10 indicates high multicollinearity), excluding 'const'
high_vif_features = vif_data[(vif_data["VIF"] > 10) & (vif_data["feature"] != "const")]["feature"].tolist()
X_poly_df_reduced = X_poly_df.drop(columns=high_vif_features)

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_poly_df_reduced, y, test_size=0.2, random_state=42)

# Train Elastic Net regression model with cross-validation to find the best alpha and l1_ratio
elastic_net = ElasticNet(max_iter=100000)
param_grid = {
    'alpha': np.logspace(-4, 4, 9),  # Adjusted range
    'l1_ratio': np.linspace(0.1, 0.9, 9)  # Avoiding extremes
}
elastic_net_cv = GridSearchCV(elastic_net, param_grid, cv=5, scoring='r2')
elastic_net_cv.fit(X_train, y_train)

# Best alpha and l1_ratio
best_params = elastic_net_cv.best_params_
print(f"Best parameters for Elastic Net: {best_params}")

# Train the initial Elastic Net regression model with the best parameters
initial_elastic_net_model = ElasticNet(alpha=best_params['alpha'], l1_ratio=best_params['l1_ratio'], max_iter=100000)
initial_elastic_net_model.fit(X_train, y_train)

# Evaluate the initial model on the test set
initial_y_pred = initial_elastic_net_model.predict(X_test)
initial_r2 = r2_score(y_test, initial_y_pred)
initial_mse = mean_squared_error(y_test, initial_y_pred)
print(f"Initial Elastic Net Regression R²: {initial_r2:.4f}")
print(f"Initial Elastic Net Regression MSE: {initial_mse:.4f}")

# Perform cross-validation for the initial model
initial_cv_scores = cross_val_score(initial_elastic_net_model, X_train, y_train, cv=5, scoring='r2')
print(f"Initial Elastic Net Regression CV R²: {np.mean(initial_cv_scores):.4f} ± {np.std(initial_cv_scores):.4f}")

# Fit OLS model for p-value inspection
X_train_const = sm.add_constant(X_train)
ols_model = sm.OLS(y_train, X_train_const).fit()
print(ols_model.summary())

# Iteratively remove features with p-values > 0.05
while True:
    p_values = ols_model.pvalues
    max_p_value = p_values.max()
    if max_p_value > 0.05:
        excluded_feature = p_values.idxmax()
        X_train_const = X_train_const.drop(columns=excluded_feature)
        X_train = X_train.drop(columns=excluded_feature)
        X_test = X_test.drop(columns=excluded_feature)
        ols_model = sm.OLS(y_train, X_train_const).fit()
    else:
        break

print(ols_model.summary())

# Train the final Elastic Net regression model
final_elastic_net_model = ElasticNet(alpha=best_params['alpha'], l1_ratio=best_params['l1_ratio'], max_iter=100000)
final_elastic_net_model.fit(X_train, y_train)

# Evaluate the final model on the test set
final_y_pred = final_elastic_net_model.predict(X_test)
final_r2 = r2_score(y_test, final_y_pred)
final_mse = mean_squared_error(y_test, final_y_pred)
print(f"Final Elastic Net Regression R²: {final_r2:.4f}")
print(f"Final Elastic Net Regression MSE: {final_mse:.4f}")

# Perform cross-validation for the final model
final_cv_scores = cross_val_score(final_elastic_net_model, X_train, y_train, cv=5, scoring='r2')
print(f"Final Elastic Net Regression CV R²: {np.mean(final_cv_scores):.4f} ± {np.std(final_cv_scores):.4f}")

# Plot actual vs predicted for final model
plt.figure(figsize=(8, 6))
plt.scatter(y_test, final_y_pred, alpha=0.5)
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'r--')
plt.xlabel('Actual')
plt.ylabel('Predicted')
plt.title('Actual vs Predicted Productivity (Final Elastic Net Model)')
plt.show()

# Plot residuals for final model
final_residuals = y_test - final_y_pred
plt.figure(figsize=(8, 6))
plt.scatter(final_y_pred, final_residuals, alpha=0.5)
plt.hlines(0, xmin=final_y_pred.min(), xmax=final_y_pred.max(), colors='r', linestyles='dashed')
plt.xlabel('Predicted')
plt.ylabel('Residuals')
plt.title('Residuals Plot (Final Elastic Net Model)')
plt.show()
# Out:
#    Total service life time (hours)  Service and maintenance condition  \
# 0                     53514.212584                                  2
# 1                    118229.241442                                  1
# 2                     53460.509897                                  4
# 3                     57294.128863                                  2
# 4                    142958.569988                                  2
#
#    Type of blade  Maximum blade capacity (m³)  Blade sharpness  Ripper used?  \
# 0              3                          8.8                1             1
# 1              3                         11.8                1             0
# 2              3                          8.8                3             0
# 3              3                         11.8                4             0
# 4              4                         11.8                4             1
#
#    Time between gear shifting (seconds)  Operator’s skill  \
# 0                                     1                 2
# 1                                     2                 4
# 2                                     1                 1
# 3                                     3                 2
# 4                                     1                 1
#
#    Overall operator’s condition during the operation  Site management quality  \
# 0                                                  4                        4
# 1                                                  4                        2
# 2                                                  1                        3
# 3                                                  2                        1
# 4                                                  2                        3
#
#    Number of consecutive operational days  Predominant soil type  \
# 0                               16.060429                      4
# 1                               70.709516                      5
# 2                               20.407878                      4
# 3                               13.973848                      1
# 4                               35.182440                      3
#
#    Big pieces of rock exist on the site?  Equipment maneuvering space  \
# 0                                      2                            4
# 1                                      2                            1
# 2                                      2                            3
# 3                                      1                            2
# 4                                      1                            1
#
#    Ground grade (%)  Dozing distance (m)  Operation time  \
# 0        -21.006882           102.332396               3
# 1          4.066639            93.733373               2
# 2          3.467018           106.859501               1
# 3         -3.603716            86.927388               2
# 4         -2.041771           140.332529               2
#
#    Average temperature during operation (°C)  \
# 0                                  19.156108
# 1                                  28.007020
# 2                                  18.014584
# 3                                   2.517283
# 4                                  -6.393585
#
#    Actual Measured Productivity (Lm³/Hour)
# 0                                52.969901
# 1                                45.649896
# 2                                41.310755
# 3                                35.679127
# 4                                50.335128
# C:\Users\tugbe\anaconda3\lib\site-packages\statsmodels\regression\linear_model.py:1736: RuntimeWarning: invalid value encountered in double_scalars
#   return 1 - self.ssr/self.centered_tss
#                                     feature           VIF
# 0                                     const  3.865729e+01
# 1           Total service life time (hours)  9.773322e+00
# 2    Number of consecutive operational days  1.011590e+01
# 3                          Ground grade (%)  9.765793e+00
# 4                       Dozing distance (m)  9.794161e+00
# ..                                      ...           ...
# 115         Ripper used?_1 Operation time_2  3.408538e+00
# 116         Ripper used?_1 Operation time_3  3.449915e+00
# 117                      Operation time_2^2  7.447695e+06
# 118       Operation time_2 Operation time_3           NaN
# 119                      Operation time_3^2  7.325602e+03
#
# [120 rows x 2 columns]
# Best parameters for Elastic Net: {'alpha': 0.01, 'l1_ratio': 0.9}
# Initial Elastic Net Regression R²: 0.6983
# Initial Elastic Net Regression MSE: 18.8287
# Initial Elastic Net Regression CV R²: 0.7071 ± 0.0055
#                                        OLS Regression Results
# ===================================================================================================
# Dep. Variable:     Actual Measured Productivity (Lm³/Hour)   R-squared:                       0.721
# Model:                                                 OLS   Adj. R-squared:                  0.715
# Method:                                      Least Squares   F-statistic:                     108.6
# Date:                                     Sun, 23 Jun 2024   Prob (F-statistic):               0.00
# Time:                                             16:48:56   Log-Likelihood:                -11443.
# No. Observations:                                     4000   AIC:                         2.307e+04
# Df Residuals:                                         3906   BIC:                         2.367e+04
# Df Model:                                               93
# Covariance Type:                                 nonrobust
# ====================================================================================================================================================
#                                                                                        coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------------------------------------------
# const                                                                               38.4314      0.209    183.704      0.000      38.021      38.842
# Total service life time (hours)                                                      0.5022      0.212      2.373      0.018       0.087       0.917
# Ground grade (%)                                                                     0.1534      0.209      0.733      0.464      -0.257       0.563
# Dozing distance (m)                                                                  4.7075      0.210     22.395      0.000       4.295       5.120
# Average temperature during operation (°C)                                            1.9848      0.213      9.334      0.000       1.568       2.402
# Total service life time (hours)^2                                                    0.0413      0.076      0.541      0.588      -0.108       0.191
# Total service life time (hours) Number of consecutive operational days              -0.1242      0.069     -1.793      0.073      -0.260       0.012
# Total service life time (hours) Ground grade (%)                                     0.0857      0.068      1.254      0.210      -0.048       0.220
# Total service life time (hours) Dozing distance (m)                                  0.0584      0.069      0.843      0.399      -0.077       0.194
# Total service life time (hours) Average temperature during operation (°C)           -0.0138      0.069     -0.201      0.841      -0.148       0.121
# Total service life time (hours) Type of blade_2                                     -0.1034      0.195     -0.529      0.597      -0.487       0.280
# Total service life time (hours) Type of blade_3                                     -0.1820      0.194     -0.939      0.348      -0.562       0.198
# Total service life time (hours) Type of blade_4                                     -0.1165      0.196     -0.595      0.552      -0.501       0.268
# Total service life time (hours) Maximum blade capacity (m³)_6.8                      0.3046      0.191      1.597      0.110      -0.069       0.679
# Total service life time (hours) Maximum blade capacity (m³)_8.8                     -0.1675      0.196     -0.853      0.394      -0.553       0.218
# Total service life time (hours) Maximum blade capacity (m³)_11.8                     0.0086      0.196      0.044      0.965      -0.376       0.393
# Total service life time (hours) Ripper used?_1                                       0.0690      0.137      0.503      0.615      -0.200       0.338
# Total service life time (hours) Operation time_2                                     0.0586      0.168      0.350      0.727      -0.270       0.388
# Total service life time (hours) Operation time_3                                     0.0875      0.169      0.517      0.605      -0.244       0.419
# Number of consecutive operational days^2                                             0.1474      0.076      1.932      0.053      -0.002       0.297
# Number of consecutive operational days Ground grade (%)                              0.1568      0.069      2.286      0.022       0.022       0.291
# Number of consecutive operational days Dozing distance (m)                           0.0151      0.068      0.221      0.825      -0.119       0.149
# Number of consecutive operational days Average temperature during operation (°C)    -0.0119      0.068     -0.176      0.861      -0.145       0.121
# Number of consecutive operational days Type of blade_2                               0.0667      0.178      0.375      0.707      -0.282       0.415
# Number of consecutive operational days Type of blade_3                              -0.1154      0.173     -0.668      0.504      -0.454       0.223
# Number of consecutive operational days Type of blade_4                               0.0372      0.172      0.216      0.829      -0.301       0.375
# Number of consecutive operational days Maximum blade capacity (m³)_6.8               0.1024      0.171      0.598      0.550      -0.234       0.438
# Number of consecutive operational days Maximum blade capacity (m³)_8.8               0.1601      0.173      0.925      0.355      -0.179       0.499
# Number of consecutive operational days Maximum blade capacity (m³)_11.8             -0.0279      0.175     -0.160      0.873      -0.370       0.314
# Number of consecutive operational days Ripper used?_1                                0.3563      0.130      2.735      0.006       0.101       0.612
# Number of consecutive operational days Operation time_2                              0.2834      0.154      1.845      0.065      -0.018       0.585
# Number of consecutive operational days Operation time_3                             -0.0243      0.157     -0.154      0.878      -0.333       0.284
# Ground grade (%)^2                                                                   0.0169      0.076      0.222      0.824      -0.133       0.166
# Ground grade (%) Dozing distance (m)                                                -0.1274      0.069     -1.842      0.066      -0.263       0.008
# Ground grade (%) Average temperature during operation (°C)                          -0.0161      0.068     -0.235      0.814      -0.150       0.118
# Ground grade (%) Type of blade_2                                                    -0.2225      0.196     -1.137      0.256      -0.606       0.161
# Ground grade (%) Type of blade_3                                                    -0.2831      0.195     -1.454      0.146      -0.665       0.099
# Ground grade (%) Type of blade_4                                                    -0.2398      0.194     -1.238      0.216      -0.620       0.140
# Ground grade (%) Maximum blade capacity (m³)_6.8                                     0.0405      0.191      0.212      0.832      -0.333       0.414
# Ground grade (%) Maximum blade capacity (m³)_8.8                                    -0.0612      0.193     -0.316      0.752      -0.440       0.318
# Ground grade (%) Maximum blade capacity (m³)_11.8                                   -0.2762      0.194     -1.427      0.154      -0.656       0.103
# Ground grade (%) Ripper used?_1                                                      0.0682      0.136      0.501      0.616      -0.199       0.335
# Ground grade (%) Operation time_2                                                    0.2745      0.165      1.659      0.097      -0.050       0.599
# Ground grade (%) Operation time_3                                                    0.1037      0.168      0.618      0.537      -0.225       0.433
# Dozing distance (m)^2                                                               -0.1021      0.077     -1.325      0.185      -0.253       0.049
# Dozing distance (m) Average temperature during operation (°C)                       -0.0177      0.069     -0.256      0.798      -0.153       0.118
# Dozing distance (m) Type of blade_2                                                 -0.0336      0.197     -0.170      0.865      -0.420       0.353
# Dozing distance (m) Type of blade_3                                                 -0.2478      0.193     -1.285      0.199      -0.626       0.130
# Dozing distance (m) Type of blade_4                                                  0.0789      0.193      0.410      0.682      -0.299       0.457
# Dozing distance (m) Maximum blade capacity (m³)_6.8                                 -0.1839      0.192     -0.958      0.338      -0.560       0.192
# Dozing distance (m) Maximum blade capacity (m³)_8.8                                  0.0295      0.194      0.152      0.879      -0.351       0.410
# Dozing distance (m) Maximum blade capacity (m³)_11.8                                -0.3950      0.195     -2.025      0.043      -0.777      -0.013
# Dozing distance (m) Ripper used?_1                                                   0.1100      0.137      0.801      0.423      -0.159       0.379
# Dozing distance (m) Operation time_2                                                -0.2123      0.167     -1.272      0.203      -0.539       0.115
# Dozing distance (m) Operation time_3                                                -0.2136      0.170     -1.257      0.209      -0.547       0.119
# Average temperature during operation (°C)^2                                          0.0415      0.076      0.543      0.587      -0.108       0.191
# Average temperature during operation (°C) Type of blade_2                           -0.0549      0.195     -0.281      0.779      -0.437       0.328
# Average temperature during operation (°C) Type of blade_3                           -0.2325      0.195     -1.193      0.233      -0.615       0.150
# Average temperature during operation (°C) Type of blade_4                            0.0596      0.196      0.304      0.761      -0.325       0.444
# Average temperature during operation (°C) Maximum blade capacity (m³)_6.8           -0.1453      0.190     -0.764      0.445      -0.518       0.228
# Average temperature during operation (°C) Maximum blade capacity (m³)_8.8           -0.1787      0.195     -0.917      0.359      -0.561       0.203
# Average temperature during operation (°C) Maximum blade capacity (m³)_11.8          -0.3144      0.193     -1.628      0.104      -0.693       0.064
# Average temperature during operation (°C) Ripper used?_1                            -0.0090      0.137     -0.066      0.947      -0.277       0.259
# Average temperature during operation (°C) Operation time_2                          -0.0495      0.166     -0.297      0.766      -0.376       0.277
# Average temperature during operation (°C) Operation time_3                          -0.0752      0.168     -0.448      0.654      -0.404       0.254
# Type of blade_2 Type of blade_3                                                   7.309e-16   2.96e-16      2.468      0.014     1.5e-16    1.31e-15
# Type of blade_2 Type of blade_4                                                  -1.284e-15   4.16e-16     -3.087      0.002    -2.1e-15   -4.69e-16
# Type of blade_2 Maximum blade capacity (m³)_6.8                                     -1.6728      0.375     -4.459      0.000      -2.408      -0.937
# Type of blade_2 Maximum blade capacity (m³)_8.8                                     -1.2659      0.394     -3.212      0.001      -2.038      -0.493
# Type of blade_2 Maximum blade capacity (m³)_11.8                                    -1.3373      0.386     -3.466      0.001      -2.094      -0.581
# Type of blade_2 Ripper used?_1                                                       4.7147      0.318     14.824      0.000       4.091       5.338
# Type of blade_2 Operation time_2                                                    -0.4469      0.336     -1.329      0.184      -1.106       0.213
# Type of blade_2 Operation time_3                                                     0.2369      0.358      0.662      0.508      -0.464       0.938
# Type of blade_3 Type of blade_4                                                   3.063e-16   2.97e-16      1.030      0.303   -2.77e-16     8.9e-16
# Type of blade_3 Maximum blade capacity (m³)_6.8                                     -0.9392      0.370     -2.536      0.011      -1.665      -0.213
# Type of blade_3 Maximum blade capacity (m³)_8.8                                     -1.0976      0.375     -2.929      0.003      -1.832      -0.363
# Type of blade_3 Maximum blade capacity (m³)_11.8                                    -0.4068      0.384     -1.058      0.290      -1.160       0.347
# Type of blade_3 Ripper used?_1                                                       5.1514      0.311     16.573      0.000       4.542       5.761
# Type of blade_3 Operation time_2                                                    -0.3184      0.341     -0.934      0.350      -0.987       0.350
# Type of blade_3 Operation time_3                                                     0.6878      0.362      1.900      0.057      -0.022       1.397
# Type of blade_4 Maximum blade capacity (m³)_6.8                                     -0.2397      0.377     -0.635      0.525      -0.979       0.500
# Type of blade_4 Maximum blade capacity (m³)_8.8                                      0.1448      0.376      0.386      0.700      -0.592       0.881
# Type of blade_4 Maximum blade capacity (m³)_11.8                                    -0.0367      0.383     -0.096      0.924      -0.788       0.715
# Type of blade_4 Ripper used?_1                                                       5.3746      0.316     17.030      0.000       4.756       5.993
# Type of blade_4 Operation time_2                                                     0.1601      0.335      0.478      0.632      -0.496       0.816
# Type of blade_4 Operation time_3                                                     0.7785      0.364      2.141      0.032       0.066       1.491
# Maximum blade capacity (m³)_6.8 Maximum blade capacity (m³)_8.8                  -1.632e-16   8.99e-17     -1.815      0.070    -3.4e-16    1.31e-17
# Maximum blade capacity (m³)_6.8 Maximum blade capacity (m³)_11.8                   1.21e-16   1.47e-16      0.823      0.411   -1.67e-16    4.09e-16
# Maximum blade capacity (m³)_6.8 Ripper used?_1                                       3.6652      0.305     12.017      0.000       3.067       4.263
# Maximum blade capacity (m³)_6.8 Operation time_2                                    -0.5352      0.347     -1.544      0.123      -1.215       0.144
# Maximum blade capacity (m³)_6.8 Operation time_3                                    -0.5887      0.374     -1.573      0.116      -1.322       0.145
# Maximum blade capacity (m³)_8.8 Maximum blade capacity (m³)_11.8                  1.985e-16   4.05e-17      4.900      0.000    1.19e-16    2.78e-16
# Maximum blade capacity (m³)_8.8 Ripper used?_1                                       3.5242      0.315     11.176      0.000       2.906       4.142
# Maximum blade capacity (m³)_8.8 Operation time_2                                    -0.5089      0.362     -1.406      0.160      -1.219       0.201
# Maximum blade capacity (m³)_8.8 Operation time_3                                     0.1516      0.356      0.425      0.671      -0.547       0.851
# Maximum blade capacity (m³)_11.8 Ripper used?_1                                      3.6408      0.315     11.541      0.000       3.022       4.259
# Maximum blade capacity (m³)_11.8 Operation time_2                                   -0.5475      0.363     -1.507      0.132      -1.260       0.165
# Maximum blade capacity (m³)_11.8 Operation time_3                                   -0.1751      0.373     -0.470      0.639      -0.906       0.556
# Ripper used?_1 Operation time_2                                                      3.4800      0.281     12.363      0.000       2.928       4.032
# Ripper used?_1 Operation time_3                                                      3.4258      0.285     12.011      0.000       2.867       3.985
# Operation time_2 Operation time_3                                                         0          0        nan        nan           0           0
# ==============================================================================
# Omnibus:                        1.162   Durbin-Watson:                   2.008
# Prob(Omnibus):                  0.559   Jarque-Bera (JB):                1.165
# Skew:                           0.042   Prob(JB):                        0.558
# Kurtosis:                       2.994   Cond. No.                     1.15e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 2.12e-28. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
#                                        OLS Regression Results
# ===================================================================================================
# Dep. Variable:     Actual Measured Productivity (Lm³/Hour)   R-squared:                       0.717
# Model:                                                 OLS   Adj. R-squared:                  0.715
# Method:                                      Least Squares   F-statistic:                     419.6
# Date:                                     Sun, 23 Jun 2024   Prob (F-statistic):               0.00
# Time:                                             16:48:56   Log-Likelihood:                -11473.
# No. Observations:                                     4000   AIC:                         2.300e+04
# Df Residuals:                                         3975   BIC:                         2.315e+04
# Df Model:                                               24
# Covariance Type:                                 nonrobust
# ===================================================================================================================================
#                                                                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------------------------------------
# const                                                              38.6237      0.104    370.367      0.000      38.419      38.828
# Total service life time (hours)                                     0.4212      0.079      5.307      0.000       0.266       0.577
# Dozing distance (m)                                                 4.5184      0.078     57.794      0.000       4.365       4.672
# Average temperature during operation (°C)                           1.7249      0.068     25.528      0.000       1.592       1.857
# Total service life time (hours) Maximum blade capacity (m³)_6.8     0.3286      0.154      2.135      0.033       0.027       0.630
# Number of consecutive operational days Ground grade (%)             0.1541      0.068      2.276      0.023       0.021       0.287
# Number of consecutive operational days Ripper used?_1               0.4009      0.105      3.829      0.000       0.196       0.606
# Number of consecutive operational days Operation time_2             0.2813      0.127      2.212      0.027       0.032       0.531
# Dozing distance (m) Maximum blade capacity (m³)_11.8               -0.3418      0.159     -2.156      0.031      -0.653      -0.031
# Type of blade_2 Maximum blade capacity (m³)_6.8                    -1.8024      0.332     -5.435      0.000      -2.453      -1.152
# Type of blade_2 Maximum blade capacity (m³)_8.8                    -1.2619      0.340     -3.708      0.000      -1.929      -0.595
# Type of blade_2 Maximum blade capacity (m³)_11.8                   -1.3230      0.325     -4.068      0.000      -1.961      -0.685
# Type of blade_2 Ripper used?_1                                      4.6602      0.286     16.287      0.000       4.099       5.221
# Type of blade_3 Maximum blade capacity (m³)_6.8                    -0.8727      0.312     -2.797      0.005      -1.484      -0.261
# Type of blade_3 Maximum blade capacity (m³)_8.8                    -0.8579      0.315     -2.720      0.007      -1.476      -0.240
# Type of blade_3 Ripper used?_1                                      5.0833      0.266     19.084      0.000       4.561       5.606
# Type of blade_4 Ripper used?_1                                      5.6565      0.251     22.515      0.000       5.164       6.149
# Maximum blade capacity (m³)_6.8 Ripper used?_1                      3.4697      0.260     13.331      0.000       2.959       3.980
# Maximum blade capacity (m³)_6.8 Operation time_2                   -0.7462      0.287     -2.598      0.009      -1.309      -0.183
# Maximum blade capacity (m³)_8.8 Ripper used?_1                      3.5971      0.271     13.294      0.000       3.067       4.128
# Maximum blade capacity (m³)_8.8 Operation time_2                   -0.8033      0.303     -2.654      0.008      -1.397      -0.210
# Maximum blade capacity (m³)_11.8 Ripper used?_1                     3.4808      0.264     13.188      0.000       2.963       3.998
# Maximum blade capacity (m³)_11.8 Operation time_2                  -0.8316      0.292     -2.845      0.004      -1.405      -0.259
# Ripper used?_1 Operation time_2                                     3.4841      0.251     13.880      0.000       2.992       3.976
# Ripper used?_1 Operation time_3                                     3.6188      0.220     16.441      0.000       3.187       4.050
# Operation time_2 Operation time_3                                        0          0        nan        nan           0           0
# ==============================================================================
# Omnibus:                        1.525   Durbin-Watson:                   2.015
# Prob(Omnibus):                  0.466   Jarque-Bera (JB):                1.551
# Skew:                           0.047   Prob(JB):                        0.461
# Kurtosis:                       2.977   Cond. No.                     1.11e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 3.99e-29. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# Final Elastic Net Regression R²: 0.6976
# Final Elastic Net Regression MSE: 18.8724
# Final Elastic Net Regression CV R²: 0.7126 ± 0.0050
